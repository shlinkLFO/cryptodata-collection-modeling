# %% [markdown]
# Walk-Forward Validation / Rolling Forecast Origin

# %% [markdown]
# General Hierarchy of Hyperparameter Importance (often, but context matters):
#
# 1. eta (learning_rate) & n_estimators: These are highly impactful and strongly linked. Lower eta generally requires higher n_estimators for convergence. Finding a good balance is crucial for performance.
# 2. max_depth: Controls the complexity of individual trees. Very important for preventing overfitting/underfitting.
# 3. subsample & colsample_bytree (or _bylevel, _bynode): Introduce stochasticity, reducing variance and preventing overfitting. Often provide good gains.
# 4. min_child_weight: Acts as a regularizer, particularly useful on imbalanced datasets to prevent trees from focusing too much on single outlier instances of the minority class.
# 5. gamma (min_split_loss): Another regularization parameter, controlling whether a split is made based on loss reduction.
# 6. Regularization (lambda, alpha): L2 and L1 regularization help prevent overfitting by shrinking weights. They are important, but often fine-tuning them yields smaller gains compared to getting the core structure (max_depth, eta/n_estimators) right, unless you have severe overfitting issues.

# %% [markdown]
# Here are typical considerations for fixed values:
#
# 1. gamma (min_split_loss):
# Purpose: Controls the minimum loss reduction needed to make a split. Higher values lead to fewer splits (more conservative).
# Default: 0 (allows any split that reduces loss, even slightly).
# Typical Fixed Value: 0. Sticking with the default is very common if you are not tuning it. It allows the tree to grow based purely on loss improvement.
# Slightly More Conservative Fixed Value: Sometimes people might use a very small value like 0.1 or 0.2 if they want to introduce a tiny barrier against splitting on minimal gains, but usually, it's kept at 0 unless tuned.
# Range Idea: Think 0 to ~1 as the area of most impact; values much larger quickly prune the tree heavily.
#
# 2. lambda (reg_lambda / L2 Regularization):
# Purpose: Penalizes large weights using the square of their magnitude. Encourages smaller, more distributed weights, good for preventing overfitting when features might be correlated.
# Default: 1. This already provides a moderate amount of L2 regularization.
# Typical Fixed Value: 1. The default is a very sensible starting point and often used as the fixed value.
# Alternative Moderate Fixed Values: Values between 0.5 and 2 are generally considered moderate L2 regularization. You could fix it at 1.5 (like you had) or 1 without drastically changing the regularization strength compared to the default.
# Range Idea: 0 means no L2. Values from 0.1 to 10 cover a wide range from weak to strong regularization.
#
# 3. alpha (reg_alpha / L1 Regularization):
# Purpose: Penalizes large weights using their absolute magnitude. Can drive feature weights to exactly zero, performing implicit feature selection.
# Default: 0 (no L1 regularization).
# Typical Fixed Value: 0. If you don't have a specific reason to encourage sparsity or perform L1 feature selection, leaving it at the default is standard practice.
# Slightly More Conservative Fixed Value: If you suspect some L1 might help a little without tuning, a very small value like 0.01 or 0.1 might be chosen. But often, if L1 is desired, it's added to the tuning grid.
# Range Idea: Similar to lambda, 0 means no L1, and values from 0.1 to 10 cover weak to strong L1 effects.
#
# Summary for Fixed Values (when not tuning):
#
# Most Common / Standard Defaults:
#
# gamma: 0
# lambda: 1
# alpha: 0
#
# Slightly Modified Defaults (if desired):
#
# gamma: 0 or 0.1
# lambda: 1 or 1.5
# alpha: 0 or 0.1

# %%
# Combined Script: Load CSV -> Feature Engineering -> Rolling Origin XGB Modeling

import pandas as pd
import numpy as np
import time
import os
import warnings
from datetime import datetime
import traceback

# Feature Engineering Imports
import pandas_ta as ta  # Technical indicators

# Modeling Imports
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, log_loss
from sklearn.model_selection import ParameterGrid
from sklearn.exceptions import UndefinedMetricWarning

# --- Suppress Warnings ---
warnings.filterwarnings('ignore', category=UndefinedMetricWarning)
warnings.filterwarnings('ignore', category=FutureWarning, module='xgboost')
warnings.filterwarnings('ignore', category=UserWarning, module='xgboost.sklearn')
warnings.filterwarnings('ignore', category=pd.errors.PerformanceWarning) # Ignore pandas performance warnings
warnings.filterwarnings('ignore') # General suppression for others if needed

# --- Configuration ---

# Data Loading
CSV_FILE_PATH = r'C:\Users\mason\AVP\BTCUSD.csv' # Use raw string for Windows paths
SYMBOL_NAME = 'BTCUSD' # Define the symbol represented in the CSV

# Feature Engineering (No longer needed: REQUIRED_OVERLAP_HOURS)

# Modeling & Walk-Forward
TARGET_THRESHOLD_PCT = 0.1 # Target threshold percentage variable

# Walk-forward params (Assuming HOURLY data in CSV)
TRAIN_WINDOW_HOURS = 175 # Example: ~1 week training
TEST_WINDOW_HOURS = 24   # Example: Predict next 24 hours
STEP_HOURS = 12          # Example: Step forward 12 hours each iteration

# Convert time durations to rows (1 row = 1 hour)
TRAIN_WINDOW_ROWS = TRAIN_WINDOW_HOURS
TEST_WINDOW_ROWS = TEST_WINDOW_HOURS
STEP_ROWS = STEP_HOURS

# Inner Cross-Validation Grid Search Configuration (Keep small)
INNER_CV_PARAM_GRID = {
    'max_depth': [3, 4],
    'n_estimators': [100, 200],
    'eta': [0.05, 0.1],
}
INNER_CV_VALIDATION_PCT = 0.20 # Use last 20% of training data for quick validation

# Fixed XGBoost parameters
XGB_FIXED_PARAMS = {
    'objective': 'binary:logistic',
    'eval_metric': 'logloss',
    'colsample_bytree': 0.8,
    'min_child_weight': 2,
    'subsample': 0.8,
    'gamma': 0.05,
    'alpha': 0.3,
    'lambda': 1.7, # L2 regularization
    'random_state': 42,
    'n_jobs': -1,
    # Uncomment for GPU if available and configured
    'tree_method': 'gpu_hist',
    'predictor': 'gpu_predictor'
}

# --- Feature Engineering Function (Adapted from Script 1) ---

def calculate_advanced_features(df, symbol):
    """Calculate all the advanced features from OHLCV data"""
    print("Starting feature calculation...")
    if df is None or len(df) < 3:
        print("Input DataFrame is too small or None.")
        return pd.DataFrame()

    df = df.copy()
    df['symbol'] = symbol # Add symbol column needed by some logic/output structure

    # Ensure timestamp is datetime and set as index temporarily
    if 'timestamp' not in df.columns:
        print("Error: 'timestamp' column not found.")
        return pd.DataFrame()
    try:
        df['timestamp'] = pd.to_datetime(df['timestamp'])
    except Exception as e:
        print(f"Error converting timestamp column to datetime: {e}")
        return pd.DataFrame()

    df = df.sort_values('timestamp')
    if df['timestamp'].isnull().any():
         print("Warning: NaN values found in timestamp after conversion. Dropping rows.")
         df = df.dropna(subset=['timestamp'])

    df = df.set_index('timestamp', drop=False)

    # Rename volume columns if they exist (handle potential missing cols)
    if 'volumefrom' in df.columns:
         df['volume_btc'] = df['volumefrom']
    elif 'Volume BTC' in df.columns:
         df['volume_btc'] = df['Volume BTC']
    else:
         print("Warning: 'volumefrom' or 'Volume BTC' column not found. Volume features may fail.")
         df['volume_btc'] = 0 # Add dummy column

    if 'volumeto' in df.columns:
         df['volume_usd'] = df['volumeto']
    elif 'Volume USD' in df.columns:
         df['volume_usd'] = df['Volume USD']
    else:
         print("Warning: 'volumeto' or 'Volume USD' column not found.")
         df['volume_usd'] = 0 # Add dummy column

    # Basic Checks
    required_cols = ['open', 'high', 'low', 'close', 'volume_btc']
    for col in required_cols:
        if col not in df.columns:
            print(f"Error: Required column '{col}' not found in DataFrame.")
            return pd.DataFrame()
        # Ensure numeric types
        df[col] = pd.to_numeric(df[col], errors='coerce')

    if df[required_cols].isnull().any().any():
        print(f"Warning: NaNs found in required OHLCV columns. Rows before drop: {len(df)}")
        df = df.dropna(subset=required_cols)
        print(f"Rows after dropping NaNs in OHLCV: {len(df)}")
        if df.empty: return pd.DataFrame()

    # Time-Based Features
    hour_of_day = df.index.hour
    day_of_week = df.index.dayofweek
    for hour in range(24):
        df[f'hour_{hour}'] = (hour_of_day == hour).astype(int)
    for day in range(7):
        df[f'day_{day}'] = (day_of_week == day).astype(int)

    # Basic Price & Volume Changes
    df['price_return_1h'] = df['close'].pct_change()
    df['oc_change_pct'] = (df['close'] - df['open']) / df['open']
    df['price_range_pct'] = (df['high'] - df['low']) / df['low']
    df['volume_return_1h'] = df['volume_btc'].pct_change()

    # Moving Averages and Rolling Std (min_periods set to 2 or full window as needed)
    min_periods_base = 2
    for hours in [3, 6, 12, 24, 48, 72, 168]:
        if len(df) >= hours:
            df[f'ma_{hours}h'] = df['close'].rolling(window=hours, min_periods=min_periods_base).mean()
            df[f'rolling_std_{hours}h'] = df['close'].rolling(window=hours, min_periods=min_periods_base).std()
        else:
            df[f'ma_{hours}h'] = np.nan
            df[f'rolling_std_{hours}h'] = np.nan


    # Lagged Price Returns
    for hours in [3, 6, 12, 24, 48, 72, 168]:
        df[f'lag_{hours}h_price_return'] = df['close'].pct_change(periods=hours)
    # Lagged Volume Returns
    for hours in [3, 6, 12, 24]:
        df[f'lag_{hours}h_volume_return'] = df['volume_btc'].pct_change(periods=hours)

    # Volatility Measures
    log_hl = np.log(df['high'].astype(float) / df['low'].astype(float))**2
    log_co = np.log(df['close'].astype(float) / df['open'].astype(float))**2
    df['garman_klass_12h'] = np.sqrt(0.5 * log_hl.rolling(12, min_periods=min(12, len(df))).sum() - (2*np.log(2)-1) * log_co.rolling(12, min_periods=min(12, len(df))).sum()) if len(df) >= 12 else np.nan
    df['parkinson_3h'] = np.sqrt((1 / (4 * np.log(2))) * (np.log(df['high'].astype(float) / df['low'].astype(float))**2).rolling(3, min_periods=min(3, len(df))).sum()) if len(df) >= 3 else np.nan
    df['tr'] = np.maximum(df['high'] - df['low'],
                          np.maximum(abs(df['high'] - df['close'].shift(1)), abs(df['low'] - df['close'].shift(1))))
    for hours in [14, 24, 48]:
         if len(df) >= hours:
              df[f'atr_{hours}h'] = df['tr'].rolling(hours, min_periods=hours).mean()
         else:
              df[f'atr_{hours}h'] = np.nan

    # Momentum Indicators
    if len(df) >= 14:
        delta = df['close'].diff()
        gain = (delta.where(delta > 0, 0)).rolling(window=14, min_periods=14).mean()
        loss = (-delta.where(delta < 0, 0)).rolling(window=14, min_periods=14).mean()
        # Handle potential division by zero or NaN in loss
        with np.errstate(divide='ignore', invalid='ignore'):
            rs = gain / loss
            df['rsi_14h'] = (100 - (100 / (1 + rs)))
        # Replace inf resulting from loss being 0 (strong uptrend) with 100
        df['rsi_14h'] = df['rsi_14h'].replace([np.inf], 100)
        # Fill initial NaNs or NaNs from zero loss with 50 (neutral)
        df['rsi_14h'] = df['rsi_14h'].fillna(50)
    else:
        df['rsi_14h'] = 50.0 # Assign neutral if not enough data

    # MACD requires sufficient data points for EMAs
    min_ema_period = 26
    if len(df) >= min_ema_period:
        ema_12 = df['close'].ewm(span=12, adjust=False, min_periods=12).mean()
        ema_26 = df['close'].ewm(span=26, adjust=False, min_periods=26).mean()
        df['macd'] = ema_12 - ema_26
        df['macd_signal'] = df['macd'].ewm(span=9, adjust=False, min_periods=9).mean()
        df['macd_hist'] = df['macd'] - df['macd_signal']
    else:
        df['macd'] = np.nan
        df['macd_signal'] = np.nan
        df['macd_hist'] = np.nan

    # Volume-Based Indicators
    for hours in [12, 24, 72, 168]:
        if len(df) >= hours:
            df[f'volume_ma_{hours}h'] = df['volume_btc'].rolling(window=hours, min_periods=min_periods_base).mean()
        else:
            df[f'volume_ma_{hours}h'] = np.nan

    df['volume_div_ma_24h'] = df['volume_btc'] / df['volume_ma_24h'] # Will produce NaN/inf if volume_ma_24h is 0 or NaN

    obv = (np.sign(df['close'].diff()) * df['volume_btc']).fillna(0).cumsum()
    df['obv'] = obv
    if len(df) >= 24:
        df['obv_ma_24h'] = df['obv'].rolling(window=24, min_periods=min_periods_base).mean()
    else:
        df['obv_ma_24h'] = np.nan

    # Ratio Features
    df['close_div_ma_24h'] = df['close'] / df['ma_24h']
    df['close_div_ma_48h'] = df['close'] / df['ma_48h']
    df['close_div_ma_168h'] = df['close'] / df['ma_168h']
    df['ma12_div_ma48'] = df['ma_12h'] / df['ma_48h']
    df['ma24_div_ma168'] = df['ma_24h'] / df['ma_168h']
    df['std12_div_std72'] = df['rolling_std_12h'] / df['rolling_std_72h']
    df['atr_14_div_atr_48'] = df['atr_14h'] / df['atr_48h']

    # Normalized Price Position
    if len(df) >= 14:
        low_14 = df['low'].rolling(window=14, min_periods=14).min()
        high_14 = df['high'].rolling(window=14, min_periods=14).max()
        # Handle division by zero if high == low
        range_14 = high_14 - low_14
        df['stoch_k'] = (100 * (df['close'] - low_14) / range_14).replace(np.inf, 50).fillna(50) # Replace inf, fill NaN
        if len(df) >= 16: # Need 14 for stoch_k + 3 for rolling mean
             df['stoch_d'] = df['stoch_k'].rolling(window=3, min_periods=3).mean()
        else:
             df['stoch_d'] = np.nan
    else:
        df['stoch_k'] = 50.0
        df['stoch_d'] = np.nan

    df['z_score_24h'] = (df['close'] - df['ma_24h']) / df['rolling_std_24h'] # Handle potential division by zero later

    # Higher-Order Statistics
    if len(df) >= 24:
        df['rolling_skew_24h'] = df['price_return_1h'].rolling(window=24, min_periods=24).skew()
        df['rolling_kurt_24h'] = df['price_return_1h'].rolling(window=24, min_periods=24).kurt()
    else:
        df['rolling_skew_24h'] = np.nan
        df['rolling_kurt_24h'] = np.nan


    # Interaction Features and Non-linear Transformations
    df['volume_btc_x_range'] = df['volume_btc'] * df['price_range_pct']
    df['rolling_std_3h_sq'] = df['rolling_std_3h'] ** 2
    df['price_return_1h_sq'] = df['price_return_1h'] ** 2
    df['rolling_std_12h_sqrt'] = np.sqrt(df['rolling_std_12h'].abs()) # Use abs() before sqrt for safety

    # --- Advanced Features using pandas_ta ---
    # Create a temporary df for ta functions that might expect specific column names
    ta_df = df.rename(columns={'volume_btc': 'volume'}, errors='ignore') # Ignore error if 'volume_btc' doesn't exist

    # Check for required columns before calling ta functions
    if all(c in ta_df.columns for c in ['high', 'low', 'close']):
        # ADX/DMI
        adx_df = ta_df.ta.adx(length=14)
        if adx_df is not None and not adx_df.empty:
             df['adx_14h'] = adx_df.get('ADX_14', np.nan)
             df['plus_di_14h'] = adx_df.get('DMP_14', np.nan)
             df['minus_di_14h'] = adx_df.get('DMN_14', np.nan)
        else:
             df['adx_14h'], df['plus_di_14h'], df['minus_di_14h'] = np.nan, np.nan, np.nan

        # Accumulation/Distribution Line (requires volume)
        if 'volume' in ta_df.columns:
             df['ad_line'] = ta_df.ta.ad()
        else: df['ad_line'] = np.nan

        # Chaikin Money Flow (requires volume)
        if 'volume' in ta_df.columns:
             df['cmf_20h'] = ta_df.ta.cmf(length=20)
        else: df['cmf_20h'] = np.nan

        # Commodity Channel Index
        df['cci_20h'] = ta_df.ta.cci(length=20)

        # Bollinger Bands
        bbands_df = ta_df.ta.bbands(length=20, std=2)
        if bbands_df is not None and not bbands_df.empty:
            df['bband_width_20h'] = bbands_df.get('BBB_20_2.0', np.nan) # Bandwidth
            df['bband_pctb_20h'] = bbands_df.get('BBP_20_2.0', np.nan) # %B
        else:
             df['bband_width_20h'], df['bband_pctb_20h'] = np.nan, np.nan
    else:
        print("Warning: Missing high, low, or close columns. Skipping some pandas_ta features.")
        # Add NaN columns explicitly if base cols are missing
        df['adx_14h'], df['plus_di_14h'], df['minus_di_14h'] = np.nan, np.nan, np.nan
        df['ad_line'], df['cmf_20h'], df['cci_20h'] = np.nan, np.nan, np.nan
        df['bband_width_20h'], df['bband_pctb_20h'] = np.nan, np.nan


    # Position in Range (handle division by zero)
    range_hl = df['high'] - df['low']
    df['close_pos_in_range'] = ((df['close'] - df['low']) / range_hl).fillna(0.5) # fillna for 0 range
    df['close_pos_in_range'] = df['close_pos_in_range'].replace([np.inf, -np.inf], 0.5) # Replace inf/-inf just in case

    # --- Additional New Features ---
    # Log Returns
    df['log_return_1h'] = np.log(df['close'] / df['close'].shift(1))

    # VWAP (24h) - ensure proper volume sum and handle potential division by zero
    if 'volume_btc' in df.columns and len(df) >= 24:
        numerator = (df['close'] * df['volume_btc']).rolling(window=24, min_periods=24).sum()
        denominator = df['volume_btc'].rolling(window=24, min_periods=24).sum()
        # Handle division by zero or NaN denominator
        with np.errstate(divide='ignore', invalid='ignore'):
            df['vwap_24h'] = numerator / denominator
        df['vwap_24h'] = df['vwap_24h'].fillna(method='ffill') # Optional: forward fill VWAP NaNs
    else:
        df['vwap_24h'] = np.nan

    # Stochastic RSI using pandas_ta
    if 'close' in ta_df.columns:
        stochrsi_df = ta_df.ta.stochrsi(length=14)
        if stochrsi_df is not None and not stochrsi_df.empty:
            # Pandas-ta column names can vary slightly or include parameters
            k_col = next((col for col in stochrsi_df.columns if 'STOCHRSIk' in col), None)
            d_col = next((col for col in stochrsi_df.columns if 'STOCHRSId' in col), None)
            df['stoch_rsi_k'] = stochrsi_df[k_col] if k_col else np.nan
            df['stoch_rsi_d'] = stochrsi_df[d_col] if d_col else np.nan
        else:
            df['stoch_rsi_k'], df['stoch_rsi_d'] = np.nan, np.nan
    else:
        df['stoch_rsi_k'], df['stoch_rsi_d'] = np.nan, np.nan


    # Cleanup: reset index and replace infinities
    df = df.reset_index(drop=True) # Reset index here
    df = df.replace([np.inf, -np.inf], np.nan) # Replace any new infs

    # Define the list of ALL potential feature columns (plus identifiers/OHLCV)
    # Make sure these match the column names generated above
    all_columns = [
        'timestamp', 'symbol', 'open', 'high', 'low', 'close', 'volume_btc', 'volume_usd',
        'garman_klass_12h', 'price_range_pct', 'oc_change_pct', 'parkinson_3h',
        'ma_3h', 'rolling_std_3h', 'lag_3h_price_return', 'lag_6h_price_return',
        'lag_12h_price_return', 'lag_24h_price_return', 'lag_48h_price_return',
        'lag_72h_price_return', 'lag_168h_price_return', 'volume_return_1h',
        'lag_3h_volume_return', 'lag_6h_volume_return', 'lag_12h_volume_return',
        'lag_24h_volume_return', 'ma_6h', 'ma_12h', 'ma_24h', 'ma_48h', 'ma_72h',
        'ma_168h', 'rolling_std_6h', 'rolling_std_12h', 'rolling_std_24h',
        'rolling_std_48h', 'rolling_std_72h', 'rolling_std_168h', 'atr_14h',
        'atr_24h', 'atr_48h', 'close_div_ma_24h', 'close_div_ma_48h',
        'close_div_ma_168h', 'ma12_div_ma48', 'ma24_div_ma168', 'std12_div_std72',
        'volume_btc_x_range', 'rolling_std_3h_sq', 'price_return_1h_sq',
        'rolling_std_12h_sqrt',
        'hour_0', 'hour_1', 'hour_2', 'hour_3', 'hour_4', 'hour_5', 'hour_6',
        'hour_7', 'hour_8', 'hour_9', 'hour_10', 'hour_11', 'hour_12',
        'hour_13', 'hour_14', 'hour_15', 'hour_16', 'hour_17', 'hour_18',
        'hour_19', 'hour_20', 'hour_21', 'hour_22', 'hour_23',
        'day_0', 'day_1', 'day_2', 'day_3', 'day_4', 'day_5', 'day_6',
        'rsi_14h', 'macd', 'macd_signal', 'macd_hist', 'volume_ma_12h',
        'volume_ma_24h', 'volume_ma_72h', 'volume_ma_168h', 'volume_div_ma_24h',
        'obv', 'obv_ma_24h', 'atr_14_div_atr_48', 'stoch_k', 'stoch_d',
        'z_score_24h', 'rolling_skew_24h', 'rolling_kurt_24h',
        'adx_14h', 'plus_di_14h', 'minus_di_14h', 'ad_line', 'cmf_20h', 'cci_20h',
        'bband_width_20h', 'bband_pctb_20h', 'close_pos_in_range',
        'vwap_24h', 'log_return_1h', 'stoch_rsi_k', 'stoch_rsi_d'
        # Columns removed: 'price_return_1h' (used intermediate, log_return kept)
    ]

    # Ensure all defined columns exist, add missing ones as NaN
    final_cols_present = []
    for col in all_columns:
        if col in df.columns:
            final_cols_present.append(col)
        # else: # Don't add missing columns, just use what was successfully calculated
        #     print(f"Debug: Column '{col}' not found after calculation, will be excluded.")
        #     # df[col] = np.nan # Optionally add if strict schema is needed

    print(f"Feature calculation finished. Returning {len(df)} rows with {len(final_cols_present)} columns.")
    return df[final_cols_present]


# --- Main Execution Block ---
if __name__ == "__main__":

    print("--- 1. Data Loading from CSV ---")
    try:
        print(f"Loading data from: {CSV_FILE_PATH}")
        # Specify column names based on the CSV header provided
        col_names = ['unix', 'date', 'symbol_csv', 'open', 'high', 'low', 'close', 'Volume BTC', 'Volume USD']
        df_raw = pd.read_csv(CSV_FILE_PATH, header=0, names=col_names) # Read header, but assign names for clarity
        print(f"Raw data loaded. Shape: {df_raw.shape}")

        # --- Basic Preprocessing ---
        # Use 'date' as the timestamp
        df_raw['timestamp'] = pd.to_datetime(df_raw['date'])
        # Drop redundant columns
        df_raw = df_raw.drop(['unix', 'date', 'symbol_csv'], axis=1)
        # Rename volume columns for the feature function
        # The feature function handles renaming these -> volume_btc/usd
        # df_raw = df_raw.rename(columns={'Volume BTC': 'volumefrom', 'Volume USD': 'volumeto'}) # Done inside function now

        # Sort by timestamp initially
        df_raw = df_raw.sort_values('timestamp').reset_index(drop=True)

        print(f"Columns after initial processing: {df_raw.columns.tolist()}")
        if not df_raw.empty:
             print(f"Time range: {df_raw['timestamp'].min()} to {df_raw['timestamp'].max()}")
        else:
             print("DataFrame is empty after loading/initial processing.")
             exit()

    except FileNotFoundError:
        print(f"Error: CSV file not found at {CSV_FILE_PATH}")
        exit()
    except Exception as e:
        print(f"Error loading or processing CSV: {e}")
        traceback.print_exc()
        exit()

    # --- 2. Feature Engineering ---
    print("\n--- 2. Feature Engineering ---")
    feature_calc_start = time.time()
    # Pass the specific symbol name
    df_features = calculate_advanced_features(df_raw, symbol=SYMBOL_NAME)
    feature_calc_end = time.time()

    if df_features.empty:
        print("Feature calculation failed or resulted in empty DataFrame. Exiting.")
        exit()
    print(f"Feature calculation completed in {feature_calc_end - feature_calc_start:.2f} seconds.")
    print(f"Shape after feature calculation: {df_features.shape}")

    # --- 3. Data Cleaning (Post-Features) ---
    print("\n--- 3. Data Cleaning (Features) ---")
    numeric_columns = df_features.select_dtypes(include=np.number).columns
    missing_before = df_features[numeric_columns].isna().sum().sum()
    infinite_before = np.isinf(df_features[numeric_columns].replace([np.inf, -np.inf], np.nan).values).sum() # Count infs properly
    print(f"Missing/Infinite values before cleaning: {missing_before} / {infinite_before}")

    # Replace inf/-inf with NaN first, then drop rows with NaN in numeric columns
    df_features = df_features.replace([np.inf, -np.inf], np.nan)
    # Optional: decide which columns are critical for dropping NaNs
    critical_features = ['close'] + [col for col in df_features.columns if 'ma_' in col or 'rolling_std_' in col or 'return' in col] # Example critical cols
    critical_features = [col for col in critical_features if col in df_features.columns] # Ensure they exist
    rows_before_drop = len(df_features)
    df = df_features.dropna(subset=critical_features) # Drop rows missing critical features

    missing_after = df[numeric_columns].isna().sum().sum()
    infinite_after = np.isinf(df[numeric_columns].values).sum() # Should be 0 now
    print(f"Missing/Infinite values after cleaning: {missing_after} / {infinite_after}")
    print(f"Rows removed due to NaNs in critical features: {rows_before_drop - len(df)} ({((rows_before_drop - len(df)) / rows_before_drop * 100):.2f}%)")

    if df.empty:
        print("DataFrame empty after cleaning NaN features. Exiting.")
        exit()
    print(f"Shape after cleaning: {df.shape}")


    # --- 4. Modeling Target & Feature Preparation ---
    print("\n--- 4. Modeling Target & Feature Preparation ---")

    # Create dummy variables for symbols - Assuming only BTCUSD is present
    print(f"Creating dummy variables for symbol '{SYMBOL_NAME}'...")
    df['BTC'] = 1 # Since the CSV is BTCUSD, BTC is always 1
    df['SOL'] = 0 # Add SOL=0 for consistency if model expects it
    # Note: If features like 'adx_14h' etc., were calculated *per symbol* originally,
    # this approach assumes the calculation is valid for the single symbol BTCUSD.

    # Create binary target
    print(f"Creating binary target 'target' ({TEST_WINDOW_HOURS}-hour return >= {TARGET_THRESHOLD_PCT}%)...")
    # Sort for reliable shift (should already be sorted, but safety check)
    df = df.sort_values(['symbol', 'timestamp']) # Sort by symbol (even if only 1) and time
    df['future_price'] = df.groupby('symbol')['close'].shift(-TEST_WINDOW_ROWS) # Shift by test window size (in hours/rows)
    df['price_return_future'] = (df['future_price'] - df['close']) / df['close'] * 100
    df['target'] = (df['price_return_future'] >= TARGET_THRESHOLD_PCT).astype(int)
    df = df.drop(['future_price', 'price_return_future'], axis=1)

    print(f"NaN values in target before drop: {df['target'].isna().sum()} (Expected due to shift)")
    df = df.dropna(subset=['target']) # Drop rows where target cannot be calculated (end of series)
    print(f"Rows after removing NaN targets: {len(df)}")
    if df.empty:
        print("DataFrame empty after target creation/NaN drop. Exiting.")
        exit()

    # Display target distribution
    target_counts = df['target'].value_counts(normalize=True) * 100
    print("\nTarget variable distribution:")
    print(f"  0 (< {TARGET_THRESHOLD_PCT}% return): {target_counts.get(0, 0):.2f}%")
    print(f"  1 (>= {TARGET_THRESHOLD_PCT}% return): {target_counts.get(1, 0):.2f}%")

    # Final Preparation for Walk-Forward
    print("\n--- Final Preparation for Walk-Forward ---")
    df = df.sort_values('timestamp').reset_index(drop=True) # Ensure chronological order and reset index for iloc
    print(f"Final DataFrame shape for backtesting: {df.shape}")

    # Define Feature Columns for Model Training
    TARGET_COLUMN = 'target'
    # Exclude identifiers, future-leaking info (if any added), and the target itself
    EXCLUDE_COLS = [TARGET_COLUMN, 'symbol', 'timestamp', 'open', 'high', 'low', 'close', 'volume_btc', 'volume_usd'] # Also exclude basic OHLCV? Optional.
    # FEATURE_COLUMNS = [col for col in df.columns if col not in EXCLUDE_COLS and df[col].dtype in [np.int64, np.float64, np.int32, np.float32]]
    # Let's be more explicit based on the generated list + dummies
    potential_features = [
        'garman_klass_12h', 'price_range_pct', 'oc_change_pct', 'parkinson_3h',
        'ma_3h', 'rolling_std_3h', 'lag_3h_price_return', 'lag_6h_price_return',
        'lag_12h_price_return', 'lag_24h_price_return', 'lag_48h_price_return',
        'lag_72h_price_return', 'lag_168h_price_return', 'volume_return_1h',
        'lag_3h_volume_return', 'lag_6h_volume_return', 'lag_12h_volume_return',
        'lag_24h_volume_return', 'ma_6h', 'ma_12h', 'ma_24h', 'ma_48h', 'ma_72h',
        'ma_168h', 'rolling_std_6h', 'rolling_std_12h', 'rolling_std_24h',
        'rolling_std_48h', 'rolling_std_72h', 'rolling_std_168h', 'atr_14h',
        'atr_24h', 'atr_48h', 'close_div_ma_24h', 'close_div_ma_48h',
        'close_div_ma_168h', 'ma12_div_ma48', 'ma24_div_ma168', 'std12_div_std72',
        'volume_btc_x_range', 'rolling_std_3h_sq', 'price_return_1h_sq', # price_return_1h_sq might leak if not careful
        'rolling_std_12h_sqrt',
        'hour_0', 'hour_1', 'hour_2', 'hour_3', 'hour_4', 'hour_5', 'hour_6',
        'hour_7', 'hour_8', 'hour_9', 'hour_10', 'hour_11', 'hour_12',
        'hour_13', 'hour_14', 'hour_15', 'hour_16', 'hour_17', 'hour_18',
        'hour_19', 'hour_20', 'hour_21', 'hour_22', 'hour_23',
        'day_0', 'day_1', 'day_2', 'day_3', 'day_4', 'day_5', 'day_6',
        'rsi_14h', 'macd', 'macd_signal', 'macd_hist', 'volume_ma_12h',
        'volume_ma_24h', 'volume_ma_72h', 'volume_ma_168h', 'volume_div_ma_24h',
        'obv', 'obv_ma_24h', 'atr_14_div_atr_48', 'stoch_k', 'stoch_d',
        'z_score_24h', 'rolling_skew_24h', 'rolling_kurt_24h',
        'adx_14h', 'plus_di_14h', 'minus_di_14h', 'ad_line', 'cmf_20h', 'cci_20h',
        'bband_width_20h', 'bband_pctb_20h', 'close_pos_in_range',
        'vwap_24h', 'log_return_1h', 'stoch_rsi_k', 'stoch_rsi_d',
        'BTC', 'SOL' # Include dummy variables
    ]
    FEATURE_COLUMNS = [col for col in potential_features if col in df.columns] # Select only those actually present

    # Final check for NaNs/Infs in selected feature columns before modeling
    check_nan_inf = df[FEATURE_COLUMNS].isnull().sum().sum() + np.isinf(df[FEATURE_COLUMNS].values).sum()
    if check_nan_inf > 0:
        print(f"WARNING: {check_nan_inf} NaN/Infinite values detected in FEATURE_COLUMNS just before modeling loop. This might cause errors.")
        # Consider df[FEATURE_COLUMNS] = df[FEATURE_COLUMNS].fillna(df[FEATURE_COLUMNS].median()) # Example imputation
        # Or drop again: df = df.dropna(subset=FEATURE_COLUMNS)
        print("Attempting to fill remaining NaNs with column medians...")
        for col in FEATURE_COLUMNS:
             if df[col].isnull().any():
                  median_val = df[col].median()
                  df[col] = df[col].fillna(median_val)
                  print(f"  Filled NaNs in {col} with median {median_val}")
        check_nan_inf_after = df[FEATURE_COLUMNS].isnull().sum().sum() + np.isinf(df[FEATURE_COLUMNS].values).sum()
        if check_nan_inf_after > 0:
            print("ERROR: NaN/Inf values remain even after fillna. Exiting.")
            exit()
        else:
            print("NaN fill complete.")


    print(f"\n--- Feature Selection ---")
    print(f"Target Column: '{TARGET_COLUMN}'")
    print(f"Number of features selected: {len(FEATURE_COLUMNS)}")
    # print(f"Selected Features: {FEATURE_COLUMNS}") # Uncomment to see list

    # --- 5. Walk-Forward Validation Implementation ---
    print("\n--- 5. Starting Walk-Forward Validation ---")
    all_metrics = {'accuracy': [], 'precision': [], 'recall': [], 'f1': []}
    iteration_count = 0
    n_rows_total = len(df)
    current_train_start_idx = 0
    total_iterations_estimate = max(0, (n_rows_total - TRAIN_WINDOW_ROWS - TEST_WINDOW_ROWS) // STEP_ROWS +1) # Adjust estimate slightly
    print(f"Total rows: {n_rows_total}, Train Window: {TRAIN_WINDOW_ROWS} ({TRAIN_WINDOW_HOURS}h), Test Window: {TEST_WINDOW_ROWS} ({TEST_WINDOW_HOURS}h), Step: {STEP_ROWS} ({STEP_HOURS}h)")
    print(f"Estimated iterations: {total_iterations_estimate}")
    print(f"Inner CV Grid: {INNER_CV_PARAM_GRID}")
    print("-" * 30)
    start_loop_time = time.time()

    while True:
        # --- Define Window Boundaries ---
        train_end_idx = current_train_start_idx + TRAIN_WINDOW_ROWS
        test_start_idx = train_end_idx
        test_end_idx = test_start_idx + TEST_WINDOW_ROWS

        # --- Boundary Checks ---
        if test_end_idx > n_rows_total:
            print(f"\nStopping: Test window end index ({test_end_idx}) exceeds total rows ({n_rows_total}).")
            break
        if current_train_start_idx >= n_rows_total:
             print(f"\nStopping: Train window start index ({current_train_start_idx}) reached end.")
             break


        # --- Data Slicing ---
        train_df = df.iloc[current_train_start_idx : train_end_idx]
        test_df = df.iloc[test_start_idx : test_end_idx]

        # --- Data Validity Checks ---
        min_train_samples = max(50, int(0.1 * TRAIN_WINDOW_ROWS)) # Need enough samples for train/val split
        min_test_samples = 5
        if len(train_df) < min_train_samples or len(test_df) < min_test_samples:
            print(f"Skipping iter {iteration_count + 1}: Insufficient data train ({len(train_df)}/{min_train_samples}) or test ({len(test_df)}/{min_test_samples}).")
            current_train_start_idx += STEP_ROWS
            continue

        X_train_full = train_df[FEATURE_COLUMNS]
        y_train_full = train_df[TARGET_COLUMN]
        X_test = test_df[FEATURE_COLUMNS]
        y_test = test_df[TARGET_COLUMN]

        # --- Check for Single Class ---
        train_counts = y_train_full.value_counts()
        test_counts = y_test.value_counts()
        if len(train_counts) < 2:
            print(f"Skipping iter {iteration_count + 1}: Full training data has only one class ({train_counts.index.tolist()}). Train indices: {current_train_start_idx}-{train_end_idx-1}")
            current_train_start_idx += STEP_ROWS
            continue
        if len(test_counts) < 2:
            print(f"Warning iter {iteration_count + 1}: Test data has only one class ({test_counts.index.tolist()}). Metrics might be affected. Test indices: {test_start_idx}-{test_end_idx-1}")
            # Allow continuing, but metrics like precision/recall/F1 might be 0 or undefined.

        # --- Calculate scale_pos_weight (based on full training data for this window) ---
        neg_count = train_counts.get(0, 0)
        pos_count = train_counts.get(1, 0)
        scale_pos_weight_val = neg_count / pos_count if pos_count > 0 else 1.0

        # --- Inner Loop: Simple Grid Search for Hyperparameters ---
        iter_start_time = time.time()
        best_val_score = -np.inf # Using F1 score, higher is better
        best_params_iter = None

        # Split training data for inner validation
        val_size = int(len(X_train_full) * INNER_CV_VALIDATION_PCT)
        if val_size < min_test_samples or (len(X_train_full) - val_size) < min_test_samples: # Ensure both train_sub and val are usable
            print(f"Warning iter {iteration_count + 1}: Train subset or Validation set too small (Total Train: {len(X_train_full)}, Val size: {val_size}). Skipping inner CV.")
            best_params_iter = list(ParameterGrid(INNER_CV_PARAM_GRID))[0] # Use first combo as default
        else:
            X_train_sub = X_train_full[:-val_size]
            y_train_sub = y_train_full[:-val_size]
            X_val = X_train_full[-val_size:]
            y_val = y_train_full[-val_size:]

            # Check if validation sub-set has both classes
            if len(y_val.unique()) < 2 or len(y_train_sub.unique()) < 2:
                print(f"Warning iter {iteration_count + 1}: Inner train ({len(y_train_sub.unique())} classes) or validation set ({len(y_val.unique())} classes) has only one class. Skipping inner CV.")
                best_params_iter = list(ParameterGrid(INNER_CV_PARAM_GRID))[0] # Use first combo
            else:
                # Iterate through the small grid
                for params_cv in ParameterGrid(INNER_CV_PARAM_GRID):
                    try:
                        current_cv_params = {**XGB_FIXED_PARAMS, **params_cv}
                        model_cv = XGBClassifier(**current_cv_params,
                                                 scale_pos_weight=scale_pos_weight_val,
                                                 use_label_encoder=False)

                        model_cv.fit(X_train_sub, y_train_sub,
                                     eval_set=[(X_val, y_val)],
                                     early_stopping_rounds=10,
                                     verbose=False)

                        y_pred_val = model_cv.predict(X_val)
                        # Use F1 score on validation set - good for imbalance
                        val_score = f1_score(y_val, y_pred_val, average='binary', pos_label=1, zero_division=0)

                        if val_score > best_val_score:
                            best_val_score = val_score
                            best_params_iter = params_cv

                    except Exception as e_cv:
                        print(f"Error during inner CV iter {iteration_count + 1} with params {params_cv}: {e_cv}")
                        if best_params_iter is None: # If first CV try fails
                            best_params_iter = list(ParameterGrid(INNER_CV_PARAM_GRID))[0]


        # Handle case where inner CV failed entirely or was skipped
        if best_params_iter is None:
            print(f"Warning iter {iteration_count + 1}: Inner CV did not find best params (or was skipped), using default.")
            best_params_iter = list(ParameterGrid(INNER_CV_PARAM_GRID))[0] # Default to first combo

        # --- Train Final Model for this Iteration ---
        final_iter_params = {**XGB_FIXED_PARAMS, **best_params_iter}

        # Print progress less frequently
        if (iteration_count == 0) or ((iteration_count + 1) % 20 == 0) or (test_end_idx >= n_rows_total): # Print first, every 20, and last
             print(f"\nIter {iteration_count + 1}/{total_iterations_estimate}: "
                   f"Train Indices [{current_train_start_idx}:{train_end_idx-1}], "
                   f"Test Indices [{test_start_idx}:{test_end_idx-1}], "
                   f"Best Params Found: {best_params_iter}")

        current_model = XGBClassifier(**final_iter_params,
                                      scale_pos_weight=scale_pos_weight_val,
                                      use_label_encoder=False)

        try:
            # Train on the FULL training set for this window
            current_model.fit(X_train_full, y_train_full, verbose=False)

            # --- Prediction and Evaluation ---
            y_pred = current_model.predict(X_test)
            accuracy = accuracy_score(y_test, y_pred)
            precision = precision_score(y_test, y_pred, average='binary', pos_label=1, zero_division=0)
            recall = recall_score(y_test, y_pred, average='binary', pos_label=1, zero_division=0)
            f1 = f1_score(y_test, y_pred, average='binary', pos_label=1, zero_division=0)

            all_metrics['accuracy'].append(accuracy)
            all_metrics['precision'].append(precision)
            all_metrics['recall'].append(recall)
            all_metrics['f1'].append(f1)

            iteration_count += 1 # Increment successful iteration count
            iter_end_time = time.time()
            # Optional: print metrics per iteration
            # print(f"  Metrics: Acc={accuracy:.4f}, Prc={precision:.4f}, Rec={recall:.4f}, F1={f1:.4f} (took {iter_end_time - iter_start_time:.2f}s)")

        except Exception as model_err:
            print(f"ERROR during model training or prediction in Iter {iteration_count + 1}: {model_err}")
            print(f"  Train shape: {X_train_full.shape}, Test shape: {X_test.shape}")
            print(f"  Train classes: {y_train_full.value_counts().to_dict()}, Test classes: {y_test.value_counts().to_dict()}")
            # Optionally add more debug info here, e.g., check for NaNs again
            check_nan_inf_train = X_train_full.isnull().sum().sum() + np.isinf(X_train_full.values).sum()
            check_nan_inf_test = X_test.isnull().sum().sum() + np.isinf(X_test.values).sum()
            print(f"  NaN/Inf check before fit: Train={check_nan_inf_train}, Test={check_nan_inf_test}")
            # Skip this iteration's metrics if model failed
            print("  Skipping metrics for this iteration due to error.")


        # --- Move to Next Window ---
        current_train_start_idx += STEP_ROWS


    end_loop_time = time.time()
    print("-" * 30)
    loop_duration_minutes = (end_loop_time - start_loop_time) / 60
    print(f"Walk-Forward Validation finished in {end_loop_time - start_loop_time:.2f} seconds ({loop_duration_minutes:.2f} minutes).")

    # --- 6. Aggregate and Display Results ---
    print("\n--- 6. Final Results ---")
    if iteration_count > 0 and len(all_metrics['f1']) > 0 : # Check if any iterations successfully completed and added metrics
        avg_accuracy = np.mean(all_metrics['accuracy'])
        avg_precision = np.mean(all_metrics['precision'])
        avg_recall = np.mean(all_metrics['recall'])
        avg_f1 = np.mean(all_metrics['f1'])

        print("\n--- Average Walk-Forward Validation Results (XGBoost with Inner CV) ---")
        print(f"Total Folds / Successful Iterations Evaluated: {iteration_count}")
        print(f"Target Threshold: {TARGET_THRESHOLD_PCT}% increase over {TEST_WINDOW_HOURS} hours")
        print(f"Train Window: {TRAIN_WINDOW_HOURS} hours, Test Window: {TEST_WINDOW_HOURS} hours, Step: {STEP_HOURS} hours")
        print(f"Average Accuracy:  {avg_accuracy:.4f}")
        print(f"Average Precision: {avg_precision:.4f} (for class 1: return >= {TARGET_THRESHOLD_PCT}%)")
        print(f"Average Recall:    {avg_recall:.4f} (for class 1: return >= {TARGET_THRESHOLD_PCT}%)")
        print(f"Average F1-Score:  {avg_f1:.4f} (for class 1: return >= {TARGET_THRESHOLD_PCT}%)")

        std_accuracy = np.std(all_metrics['accuracy'])
        std_precision = np.std(all_metrics['precision'])
        std_recall = np.std(all_metrics['recall'])
        std_f1 = np.std(all_metrics['f1'])
        print("\n--- Standard Deviation of Metrics Across Folds ---")
        print(f"Std Dev Accuracy:  {std_accuracy:.4f}")
        print(f"Std Dev Precision: {std_precision:.4f}")
        print(f"Std Dev Recall:    {std_recall:.4f}")
        print(f"Std Dev F1-Score:  {std_f1:.4f}")
    else:
        print("\nNo iterations were successfully completed or no metrics were recorded.")

    print("\nScript finished.")
# Out:
# --- 1. Data Loading from CSV ---
# Loading data from: C:\Users\mason\AVP\BTCUSD.csv
# Raw data loaded. Shape: (60403, 9)
# Columns after initial processing: ['open', 'high', 'low', 'close', 'Volume BTC', 'Volume USD', 'timestamp']
# Time range: 2018-05-15 06:00:00 to 2025-04-05 00:00:00
#
# --- 2. Feature Engineering ---
# Starting feature calculation...
# Feature calculation finished. Returning 60403 rows with 112 columns.
# Feature calculation completed in 0.48 seconds.
# Shape after feature calculation: (60403, 112)
#
# --- 3. Data Cleaning (Features) ---
# Missing/Infinite values before cleaning: 962 / 0
# Missing/Infinite values after cleaning: 0 / 0
# Rows removed due to NaNs in critical features: 215 (0.36%)
# Shape after cleaning: (60188, 112)
#
# --- 4. Modeling Target & Feature Preparation ---
# Creating dummy variables for symbol 'BTCUSD'...
# Creating binary target 'target' (24-hour return >= 0.1%)...
# NaN values in target before drop: 0 (Expected due to shift)
# Rows after removing NaN targets: 60188
#
# Target variable distribution:
#   0 (< 0.1% return): 50.53%
#   1 (>= 0.1% return): 49.47%
#
# --- Final Preparation for Walk-Forward ---
# Final DataFrame shape for backtesting: (60188, 115)
#
# --- Feature Selection ---
# Target Column: 'target'
# Number of features selected: 106
#
# --- 5. Starting Walk-Forward Validation ---
# Total rows: 60188, Train Window: 175 (175h), Test Window: 24 (24h), Step: 12 (12h)
# Estimated iterations: 5000
# Inner CV Grid: {'max_depth': [3, 4], 'n_estimators': [100, 200], 'eta': [0.05, 0.1]}
# ------------------------------
#
# Iter 1/5000: Train Indices [0:174], Test Indices [175:198], Best Params Found: {'eta': 0.05, 'max_depth': 3, 'n_estimators': 100}
# Warning iter 7: Test data has only one class ([1]). Metrics might be affected. Test indices: 247-270
# Warning iter 8: Test data has only one class ([1]). Metrics might be affected. Test indices: 259-282
# Warning iter 10: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
# Warning iter 11: Test data has only one class ([0]). Metrics might be affected. Test indices: 295-318
# Warning iter 18: Test data has only one class ([0]). Metrics might be affected. Test indices: 379-402
#
# Iter 20/5000: Train Indices [228:402], Test Indices [403:426], Best Params Found: {'eta': 0.05, 'max_depth': 3, 'n_estimators': 100}
# Warning iter 22: Test data has only one class ([0]). Metrics might be affected. Test indices: 427-450
# Warning iter 23: Test data has only one class ([0]). Metrics might be affected. Test indices: 439-462
# Warning iter 25: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
# Warning iter 28: Test data has only one class ([0]). Metrics might be affected. Test indices: 499-522
#
# Iter 40/5000: Train Indices [468:642], Test Indices [643:666], Best Params Found: {'eta': 0.05, 'max_depth': 3, 'n_estimators': 200}
# Warning iter 45: Test data has only one class ([0]). Metrics might be affected. Test indices: 703-726
# Warning iter 46: Test data has only one class ([0]). Metrics might be affected. Test indices: 715-738
# Warning iter 47: Test data has only one class ([0]). Metrics might be affected. Test indices: 727-750
# Warning iter 48: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
# Warning iter 49: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
# Warning iter 52: Test data has only one class ([1]). Metrics might be affected. Test indices: 787-810
#
# Iter 60/5000: Train Indices [708:882], Test Indices [883:906], Best Params Found: {'eta': 0.05, 'max_depth': 3, 'n_estimators': 100}
# Warning iter 62: Test data has only one class ([1]). Metrics might be affected. Test indices: 907-930
# Warning iter 67: Test data has only one class ([1]). Metrics might be affected. Test indices: 967-990
# Warning iter 69: Test data has only one class ([0]). Metrics might be affected. Test indices: 991-1014
# Warning iter 71: Test data has only one class ([1]). Metrics might be affected. Test indices: 1015-1038
# Warning iter 73: Test data has only one class ([0]). Metrics might be affected. Test indices: 1039-1062
# Warning iter 80: Test data has only one class ([0]). Metrics might be affected. Test indices: 1123-1146
#
# Iter 80/5000: Train Indices [948:1122], Test Indices [1123:1146], Best Params Found: {'eta': 0.05, 'max_depth': 3, 'n_estimators': 100}
# Warning iter 81: Test data has only one class ([0]). Metrics might be affected. Test indices: 1135-1158
# Warning iter 82: Test data has only one class ([0]). Metrics might be affected. Test indices: 1147-1170
# Warning iter 83: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
# Warning iter 84: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
# Warning iter 86: Test data has only one class ([0]). Metrics might be affected. Test indices: 1195-1218
# Warning iter 92: Test data has only one class ([1]). Metrics might be affected. Test indices: 1267-1290
# Warning iter 93: Test data has only one class ([1]). Metrics might be affected. Test indices: 1279-1302
# Warning iter 94: Test data has only one class ([1]). Metrics might be affected. Test indices: 1291-1314
# Warning iter 95: Test data has only one class ([1]). Metrics might be affected. Test indices: 1303-1326
# Warning iter 95: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
# Warning iter 96: Test data has only one class ([1]). Metrics might be affected. Test indices: 1315-1338
# Warning iter 96: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
# Warning iter 97: Test data has only one class ([1]). Metrics might be affected. Test indices: 1327-1350
# Warning iter 97: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
# Warning iter 98: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
# Warning iter 99: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
#
# Iter 100/5000: Train Indices [1188:1362], Test Indices [1363:1386], Best Params Found: {'eta': 0.05, 'max_depth': 3, 'n_estimators': 100}
# Warning iter 108: Test data has only one class ([1]). Metrics might be affected. Test indices: 1459-1482
# Warning iter 109: Test data has only one class ([1]). Metrics might be affected. Test indices: 1471-1494
# Warning iter 110: Test data has only one class ([1]). Metrics might be affected. Test indices: 1483-1506
# Warning iter 111: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
# Warning iter 112: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
#
# Iter 120/5000: Train Indices [1428:1602], Test Indices [1603:1626], Best Params Found: {'eta': 0.05, 'max_depth': 3, 'n_estimators': 100}
# Warning iter 123: Test data has only one class ([0]). Metrics might be affected. Test indices: 1639-1662
# Warning iter 124: Test data has only one class ([0]). Metrics might be affected. Test indices: 1651-1674
# Warning iter 125: Test data has only one class ([0]). Metrics might be affected. Test indices: 1663-1686
# Warning iter 126: Test data has only one class ([0]). Metrics might be affected. Test indices: 1675-1698
# Warning iter 126: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
# Warning iter 127: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
# Warning iter 128: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
# Warning iter 133: Test data has only one class ([0]). Metrics might be affected. Test indices: 1759-1782
# Warning iter 140: Test data has only one class ([0]). Metrics might be affected. Test indices: 1843-1866
#
# Iter 140/5000: Train Indices [1668:1842], Test Indices [1843:1866], Best Params Found: {'eta': 0.05, 'max_depth': 3, 'n_estimators': 100}
# Warning iter 141: Test data has only one class ([0]). Metrics might be affected. Test indices: 1855-1878
# Warning iter 143: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
# Warning iter 152: Test data has only one class ([0]). Metrics might be affected. Test indices: 1987-2010
# Warning iter 154: Test data has only one class ([1]). Metrics might be affected. Test indices: 2011-2034
#
# Iter 160/5000: Train Indices [1908:2082], Test Indices [2083:2106], Best Params Found: {'eta': 0.05, 'max_depth': 3, 'n_estimators': 100}
# Warning iter 161: Test data has only one class ([0]). Metrics might be affected. Test indices: 2095-2118
# Warning iter 172: Test data has only one class ([1]). Metrics might be affected. Test indices: 2227-2250
# Warning iter 173: Test data has only one class ([1]). Metrics might be affected. Test indices: 2239-2262
# Warning iter 174: Test data has only one class ([1]). Metrics might be affected. Test indices: 2251-2274
# Warning iter 175: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
# Warning iter 176: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
# Warning iter 180: Test data has only one class ([1]). Metrics might be affected. Test indices: 2323-2346
#
# Iter 180/5000: Train Indices [2148:2322], Test Indices [2323:2346], Best Params Found: {'eta': 0.1, 'max_depth': 3, 'n_estimators': 100}
# Warning iter 181: Test data has only one class ([1]). Metrics might be affected. Test indices: 2335-2358
# Warning iter 182: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
# Warning iter 183: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
# Warning iter 184: Test data has only one class ([0]). Metrics might be affected. Test indices: 2371-2394
# Warning iter 187: Test data has only one class ([1]). Metrics might be affected. Test indices: 2407-2430
# Warning iter 188: Test data has only one class ([1]). Metrics might be affected. Test indices: 2419-2442
# Warning iter 189: Test data has only one class ([1]). Metrics might be affected. Test indices: 2431-2454
# Warning iter 190: Test data has only one class ([1]). Metrics might be affected. Test indices: 2443-2466
# Warning iter 190: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
# Warning iter 191: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
# Warning iter 192: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
# Warning iter 197: Test data has only one class ([0]). Metrics might be affected. Test indices: 2527-2550
#
# Iter 200/5000: Train Indices [2388:2562], Test Indices [2563:2586], Best Params Found: {'eta': 0.05, 'max_depth': 3, 'n_estimators': 100}
# Warning iter 212: Test data has only one class ([1]). Metrics might be affected. Test indices: 2707-2730
#
# Iter 220/5000: Train Indices [2628:2802], Test Indices [2803:2826], Best Params Found: {'eta': 0.1, 'max_depth': 3, 'n_estimators': 100}
# Warning iter 221: Test data has only one class ([0]). Metrics might be affected. Test indices: 2815-2838
# Warning iter 228: Test data has only one class ([1]). Metrics might be affected. Test indices: 2899-2922
# Warning iter 235: Test data has only one class ([0]). Metrics might be affected. Test indices: 2983-3006
# Warning iter 236: Test data has only one class ([0]). Metrics might be affected. Test indices: 2995-3018
# Warning iter 238: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
#
# Iter 240/5000: Train Indices [2868:3042], Test Indices [3043:3066], Best Params Found: {'eta': 0.1, 'max_depth': 3, 'n_estimators': 100}
# Warning iter 244: Test data has only one class ([0]). Metrics might be affected. Test indices: 3091-3114
# Warning iter 250: Test data has only one class ([0]). Metrics might be affected. Test indices: 3163-3186
# Warning iter 251: Test data has only one class ([0]). Metrics might be affected. Test indices: 3175-3198
# Warning iter 252: Test data has only one class ([0]). Metrics might be affected. Test indices: 3187-3210
# Warning iter 253: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
# Warning iter 254: Test data has only one class ([1]). Metrics might be affected. Test indices: 3211-3234
# Warning iter 254: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
#
# Iter 260/5000: Train Indices [3108:3282], Test Indices [3283:3306], Best Params Found: {'eta': 0.05, 'max_depth': 3, 'n_estimators': 100}
# Warning iter 265: Test data has only one class ([0]). Metrics might be affected. Test indices: 3343-3366
# Warning iter 266: Test data has only one class ([0]). Metrics might be affected. Test indices: 3355-3378
# Warning iter 267: Test data has only one class ([0]). Metrics might be affected. Test indices: 3367-3390
# Warning iter 268: Test data has only one class ([0]). Metrics might be affected. Test indices: 3379-3402
# Warning iter 268: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
# Warning iter 269: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
# Warning iter 270: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
#
# Iter 280/5000: Train Indices [3348:3522], Test Indices [3523:3546], Best Params Found: {'eta': 0.1, 'max_depth': 3, 'n_estimators': 100}
# Warning iter 290: Test data has only one class ([0]). Metrics might be affected. Test indices: 3643-3666
# Warning iter 291: Test data has only one class ([0]). Metrics might be affected. Test indices: 3655-3678
# Warning iter 293: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
# Warning iter 296: Test data has only one class ([0]). Metrics might be affected. Test indices: 3715-3738
#
# Iter 300/5000: Train Indices [3588:3762], Test Indices [3763:3786], Best Params Found: {'eta': 0.05, 'max_depth': 3, 'n_estimators': 100}
# Warning iter 304: Test data has only one class ([0]). Metrics might be affected. Test indices: 3811-3834
# Warning iter 314: Test data has only one class ([0]). Metrics might be affected. Test indices: 3931-3954
# Warning iter 317: Test data has only one class ([1]). Metrics might be affected. Test indices: 3967-3990
#
# Iter 320/5000: Train Indices [3828:4002], Test Indices [4003:4026], Best Params Found: {'eta': 0.1, 'max_depth': 3, 'n_estimators': 100}
# Warning iter 324: Test data has only one class ([0]). Metrics might be affected. Test indices: 4051-4074
# Warning iter 325: Test data has only one class ([0]). Metrics might be affected. Test indices: 4063-4086
# Warning iter 326: Test data has only one class ([0]). Metrics might be affected. Test indices: 4075-4098
# Warning iter 327: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
# Warning iter 328: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
# Warning iter 334: Test data has only one class ([0]). Metrics might be affected. Test indices: 4171-4194
# Warning iter 335: Test data has only one class ([0]). Metrics might be affected. Test indices: 4183-4206
# Warning iter 336: Test data has only one class ([0]). Metrics might be affected. Test indices: 4195-4218
# Warning iter 337: Test data has only one class ([0]). Metrics might be affected. Test indices: 4207-4230
# Warning iter 337: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
# Warning iter 338: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
# Warning iter 339: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
#
# Iter 340/5000: Train Indices [4068:4242], Test Indices [4243:4266], Best Params Found: {'eta': 0.05, 'max_depth': 3, 'n_estimators': 100}
# Warning iter 344: Test data has only one class ([1]). Metrics might be affected. Test indices: 4291-4314
# Warning iter 347: Test data has only one class ([0]). Metrics might be affected. Test indices: 4327-4350
# Warning iter 348: Test data has only one class ([0]). Metrics might be affected. Test indices: 4339-4362
# Warning iter 349: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
# Warning iter 350: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
# Warning iter 357: Test data has only one class ([0]). Metrics might be affected. Test indices: 4447-4470
#
# Iter 360/5000: Train Indices [4308:4482], Test Indices [4483:4506], Best Params Found: {'eta': 0.05, 'max_depth': 3, 'n_estimators': 100}
# Warning iter 364: Test data has only one class ([1]). Metrics might be affected. Test indices: 4531-4554
# Warning iter 365: Test data has only one class ([1]). Metrics might be affected. Test indices: 4543-4566
# Warning iter 367: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
# Warning iter 374: Test data has only one class ([0]). Metrics might be affected. Test indices: 4651-4674
#
# Iter 380/5000: Train Indices [4548:4722], Test Indices [4723:4746], Best Params Found: {'eta': 0.05, 'max_depth': 3, 'n_estimators': 100}
# Warning iter 381: Test data has only one class ([0]). Metrics might be affected. Test indices: 4735-4758
# Warning iter 387: Test data has only one class ([1]). Metrics might be affected. Test indices: 4807-4830
# Warning iter 390: Test data has only one class ([0]). Metrics might be affected. Test indices: 4843-4866
# Warning iter 392: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
# Warning iter 395: Test data has only one class ([0]). Metrics might be affected. Test indices: 4903-4926
# Warning iter 396: Test data has only one class ([0]). Metrics might be affected. Test indices: 4915-4938
# Warning iter 397: Test data has only one class ([0]). Metrics might be affected. Test indices: 4927-4950
# Warning iter 398: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
# Warning iter 399: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
#
# Iter 400/5000: Train Indices [4788:4962], Test Indices [4963:4986], Best Params Found: {'eta': 0.05, 'max_depth': 3, 'n_estimators': 100}
# Warning iter 403: Test data has only one class ([1]). Metrics might be affected. Test indices: 4999-5022
# Warning iter 406: Test data has only one class ([1]). Metrics might be affected. Test indices: 5035-5058
# Warning iter 418: Test data has only one class ([0]). Metrics might be affected. Test indices: 5179-5202
#
# Iter 420/5000: Train Indices [5028:5202], Test Indices [5203:5226], Best Params Found: {'eta': 0.05, 'max_depth': 3, 'n_estimators': 100}
# Warning iter 431: Test data has only one class ([0]). Metrics might be affected. Test indices: 5335-5358
# Warning iter 434: Test data has only one class ([1]). Metrics might be affected. Test indices: 5371-5394
# Warning iter 435: Test data has only one class ([1]). Metrics might be affected. Test indices: 5383-5406
# Warning iter 437: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
#
# Iter 440/5000: Train Indices [5268:5442], Test Indices [5443:5466], Best Params Found: {'eta': 0.05, 'max_depth': 3, 'n_estimators': 100}
# Warning iter 451: Test data has only one class ([0]). Metrics might be affected. Test indices: 5575-5598
# Warning iter 457: Test data has only one class ([0]). Metrics might be affected. Test indices: 5647-5670
#
# Iter 460/5000: Train Indices [5508:5682], Test Indices [5683:5706], Best Params Found: {'eta': 0.1, 'max_depth': 3, 'n_estimators': 100}
# Warning iter 475: Test data has only one class ([1]). Metrics might be affected. Test indices: 5863-5886
#
# Iter 480/5000: Train Indices [5748:5922], Test Indices [5923:5946], Best Params Found: {'eta': 0.05, 'max_depth': 3, 'n_estimators': 100}
# Warning iter 484: Test data has only one class ([0]). Metrics might be affected. Test indices: 5971-5994
# Warning iter 485: Test data has only one class ([0]). Metrics might be affected. Test indices: 5983-6006
# Warning iter 486: Test data has only one class ([0]). Metrics might be affected. Test indices: 5995-6018
# Warning iter 487: Test data has only one class ([0]). Metrics might be affected. Test indices: 6007-6030
# Warning iter 487: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
# Warning iter 488: Test data has only one class ([0]). Metrics might be affected. Test indices: 6019-6042
# Warning iter 488: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
# Warning iter 489: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
# Warning iter 490: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
# Warning iter 495: Test data has only one class ([1]). Metrics might be affected. Test indices: 6103-6126
# Warning iter 499: Test data has only one class ([0]). Metrics might be affected. Test indices: 6151-6174
#
# Iter 500/5000: Train Indices [5988:6162], Test Indices [6163:6186], Best Params Found: {'eta': 0.05, 'max_depth': 3, 'n_estimators': 100}
# Warning iter 504: Test data has only one class ([0]). Metrics might be affected. Test indices: 6211-6234
# Warning iter 509: Test data has only one class ([1]). Metrics might be affected. Test indices: 6271-6294
# Warning iter 519: Test data has only one class ([0]). Metrics might be affected. Test indices: 6391-6414
#
# Iter 520/5000: Train Indices [6228:6402], Test Indices [6403:6426], Best Params Found: {'eta': 0.05, 'max_depth': 3, 'n_estimators': 100}
# Warning iter 528: Test data has only one class ([1]). Metrics might be affected. Test indices: 6499-6522
# Warning iter 529: Test data has only one class ([1]). Metrics might be affected. Test indices: 6511-6534
# Warning iter 531: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
#
# Iter 540/5000: Train Indices [6468:6642], Test Indices [6643:6666], Best Params Found: {'eta': 0.05, 'max_depth': 3, 'n_estimators': 100}
# Warning iter 555: Test data has only one class ([0]). Metrics might be affected. Test indices: 6823-6846
# Warning iter 556: Test data has only one class ([0]). Metrics might be affected. Test indices: 6835-6858
# Warning iter 558: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
# Warning iter 559: Test data has only one class ([1]). Metrics might be affected. Test indices: 6871-6894
#
# Iter 560/5000: Train Indices [6708:6882], Test Indices [6883:6906], Best Params Found: {'eta': 0.1, 'max_depth': 4, 'n_estimators': 100}
# Warning iter 579: Test data has only one class ([1]). Metrics might be affected. Test indices: 7111-7134
# Warning iter 580: Test data has only one class ([1]). Metrics might be affected. Test indices: 7123-7146
#
# Iter 580/5000: Train Indices [6948:7122], Test Indices [7123:7146], Best Params Found: {'eta': 0.05, 'max_depth': 3, 'n_estimators': 100}
# Warning iter 582: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
# Warning iter 589: Test data has only one class ([1]). Metrics might be affected. Test indices: 7231-7254
# Warning iter 595: Test data has only one class ([0]). Metrics might be affected. Test indices: 7303-7326
# Warning iter 596: Test data has only one class ([0]). Metrics might be affected. Test indices: 7315-7338
# Warning iter 598: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
# Warning iter 599: Test data has only one class ([0]). Metrics might be affected. Test indices: 7351-7374
#
# Iter 600/5000: Train Indices [7188:7362], Test Indices [7363:7386], Best Params Found: {'eta': 0.1, 'max_depth': 3, 'n_estimators': 100}
# Warning iter 602: Test data has only one class ([1]). Metrics might be affected. Test indices: 7387-7410
# Warning iter 612: Test data has only one class ([1]). Metrics might be affected. Test indices: 7507-7530
# Warning iter 613: Test data has only one class ([1]). Metrics might be affected. Test indices: 7519-7542
# Warning iter 614: Test data has only one class ([1]). Metrics might be affected. Test indices: 7531-7554
# Warning iter 615: Test data has only one class ([1]). Metrics might be affected. Test indices: 7543-7566
# Warning iter 615: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
# Warning iter 616: Test data has only one class ([1]). Metrics might be affected. Test indices: 7555-7578
# Warning iter 616: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
# Warning iter 617: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
# Warning iter 618: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
#
# Iter 620/5000: Train Indices [7428:7602], Test Indices [7603:7626], Best Params Found: {'eta': 0.05, 'max_depth': 3, 'n_estimators': 100}
#
# Iter 640/5000: Train Indices [7668:7842], Test Indices [7843:7866], Best Params Found: {'eta': 0.05, 'max_depth': 3, 'n_estimators': 100}
# Warning iter 650: Test data has only one class ([1]). Metrics might be affected. Test indices: 7963-7986
# Warning iter 655: Test data has only one class ([1]). Metrics might be affected. Test indices: 8023-8046
# Warning iter 656: Test data has only one class ([1]). Metrics might be affected. Test indices: 8035-8058
# Warning iter 658: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
#
# Iter 660/5000: Train Indices [7908:8082], Test Indices [8083:8106], Best Params Found: {'eta': 0.05, 'max_depth': 3, 'n_estimators': 100}
# Warning iter 671: Test data has only one class ([1]). Metrics might be affected. Test indices: 8215-8238
# Warning iter 672: Test data has only one class ([1]). Metrics might be affected. Test indices: 8227-8250
# Warning iter 674: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
# Warning iter 675: Test data has only one class ([1]). Metrics might be affected. Test indices: 8263-8286
# Warning iter 676: Test data has only one class ([1]). Metrics might be affected. Test indices: 8275-8298
# Warning iter 678: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
#
# Iter 680/5000: Train Indices [8148:8322], Test Indices [8323:8346], Best Params Found: {'eta': 0.05, 'max_depth': 3, 'n_estimators': 100}
# Warning iter 684: Test data has only one class ([1]). Metrics might be affected. Test indices: 8371-8394
# Warning iter 688: Test data has only one class ([1]). Metrics might be affected. Test indices: 8419-8442
# Warning iter 689: Test data has only one class ([1]). Metrics might be affected. Test indices: 8431-8454
# Warning iter 690: Test data has only one class ([1]). Metrics might be affected. Test indices: 8443-8466
# Warning iter 691: Test data has only one class ([1]). Metrics might be affected. Test indices: 8455-8478
# Warning iter 691: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
# Warning iter 692: Test data has only one class ([1]). Metrics might be affected. Test indices: 8467-8490
# Warning iter 692: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
# Warning iter 693: Test data has only one class ([1]). Metrics might be affected. Test indices: 8479-8502
# Warning iter 693: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
# Warning iter 694: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
# Warning iter 695: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
# Warning iter 697: Test data has only one class ([1]). Metrics might be affected. Test indices: 8527-8550
#
# Iter 700/5000: Train Indices [8388:8562], Test Indices [8563:8586], Best Params Found: {'eta': 0.1, 'max_depth': 3, 'n_estimators': 100}
# Warning iter 704: Test data has only one class ([0]). Metrics might be affected. Test indices: 8611-8634
# Warning iter 708: Test data has only one class ([1]). Metrics might be affected. Test indices: 8659-8682
# Warning iter 718: Test data has only one class ([1]). Metrics might be affected. Test indices: 8779-8802
# Warning iter 719: Test data has only one class ([1]). Metrics might be affected. Test indices: 8791-8814
#
# Iter 720/5000: Train Indices [8628:8802], Test Indices [8803:8826], Best Params Found: {'eta': 0.1, 'max_depth': 3, 'n_estimators': 100}
# Warning iter 721: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
# Warning iter 736: Test data has only one class ([1]). Metrics might be affected. Test indices: 8995-9018
# Warning iter 739: Test data has only one class ([0]). Metrics might be affected. Test indices: 9031-9054
# Warning iter 740: Test data has only one class ([0]). Metrics might be affected. Test indices: 9043-9066
#
# Iter 740/5000: Train Indices [8868:9042], Test Indices [9043:9066], Best Params Found: {'eta': 0.05, 'max_depth': 3, 'n_estimators': 100}
# Warning iter 741: Test data has only one class ([0]). Metrics might be affected. Test indices: 9055-9078
# Warning iter 742: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
# Warning iter 743: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
# Warning iter 749: Test data has only one class ([0]). Metrics might be affected. Test indices: 9151-9174
# Warning iter 750: Test data has only one class ([0]). Metrics might be affected. Test indices: 9163-9186
# Warning iter 752: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
# Warning iter 757: Test data has only one class ([1]). Metrics might be affected. Test indices: 9247-9270
# Warning iter 759: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
# Warning iter 760: Test data has only one class ([1]). Metrics might be affected. Test indices: 9283-9306
#
# Iter 760/5000: Train Indices [9108:9282], Test Indices [9283:9306], Best Params Found: {'eta': 0.05, 'max_depth': 3, 'n_estimators': 100}
# Warning iter 761: Test data has only one class ([1]). Metrics might be affected. Test indices: 9295-9318
# Warning iter 762: Test data has only one class ([1]). Metrics might be affected. Test indices: 9307-9330
# Warning iter 763: Test data has only one class ([1]). Metrics might be affected. Test indices: 9319-9342
# Warning iter 763: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
# Warning iter 764: Test data has only one class ([1]). Metrics might be affected. Test indices: 9331-9354
# Warning iter 764: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
# Warning iter 765: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
# Warning iter 766: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
# Warning iter 772: Test data has only one class ([1]). Metrics might be affected. Test indices: 9427-9450
# Warning iter 773: Test data has only one class ([1]). Metrics might be affected. Test indices: 9439-9462
# Warning iter 774: Test data has only one class ([1]). Metrics might be affected. Test indices: 9451-9474
# Warning iter 775: Test data has only one class ([1]). Metrics might be affected. Test indices: 9463-9486
# Warning iter 775: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
# Warning iter 776: Test data has only one class ([1]). Metrics might be affected. Test indices: 9475-9498
# Warning iter 776: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
# Warning iter 777: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
# Warning iter 778: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
#
# Iter 780/5000: Train Indices [9348:9522], Test Indices [9523:9546], Best Params Found: {'eta': 0.05, 'max_depth': 3, 'n_estimators': 100}
# Warning iter 782: Test data has only one class ([1]). Metrics might be affected. Test indices: 9547-9570
# Warning iter 783: Test data has only one class ([1]). Metrics might be affected. Test indices: 9559-9582
# Warning iter 784: Test data has only one class ([1]). Metrics might be affected. Test indices: 9571-9594
# Warning iter 785: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
# Warning iter 786: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
# Warning iter 793: Test data has only one class ([0]). Metrics might be affected. Test indices: 9679-9702
# Warning iter 794: Test data has only one class ([0]). Metrics might be affected. Test indices: 9691-9714
# Warning iter 795: Test data has only one class ([0]). Metrics might be affected. Test indices: 9703-9726
# Warning iter 796: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
# Warning iter 797: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
# Warning iter 798: Test data has only one class ([1]). Metrics might be affected. Test indices: 9739-9762
# Warning iter 799: Test data has only one class ([1]). Metrics might be affected. Test indices: 9751-9774
# Warning iter 800: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
#
# Iter 800/5000: Train Indices [9588:9762], Test Indices [9763:9786], Best Params Found: {'eta': 0.05, 'max_depth': 3, 'n_estimators': 100}
# Warning iter 801: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
# Warning iter 808: Test data has only one class ([1]). Metrics might be affected. Test indices: 9859-9882
# Warning iter 809: Test data has only one class ([1]). Metrics might be affected. Test indices: 9871-9894
# Warning iter 810: Test data has only one class ([1]). Metrics might be affected. Test indices: 9883-9906
# Warning iter 811: Test data has only one class ([1]). Metrics might be affected. Test indices: 9895-9918
# Warning iter 811: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
# Warning iter 812: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
# Warning iter 813: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
# Warning iter 814: Test data has only one class ([0]). Metrics might be affected. Test indices: 9931-9954
# Warning iter 819: Test data has only one class ([0]). Metrics might be affected. Test indices: 9991-10014
# Warning iter 820: Test data has only one class ([0]). Metrics might be affected. Test indices: 10003-10026
#
# Iter 820/5000: Train Indices [9828:10002], Test Indices [10003:10026], Best Params Found: {'eta': 0.1, 'max_depth': 3, 'n_estimators': 100}
# Warning iter 821: Test data has only one class ([0]). Metrics might be affected. Test indices: 10015-10038
# Warning iter 822: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
# Warning iter 823: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
# Warning iter 837: Test data has only one class ([0]). Metrics might be affected. Test indices: 10207-10230
# Warning iter 838: Test data has only one class ([0]). Metrics might be affected. Test indices: 10219-10242
# Warning iter 839: Test data has only one class ([0]). Metrics might be affected. Test indices: 10231-10254
# Warning iter 840: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
#
# Iter 840/5000: Train Indices [10068:10242], Test Indices [10243:10266], Best Params Found: {'eta': 0.05, 'max_depth': 3, 'n_estimators': 100}
# Warning iter 841: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
# Warning iter 853: Test data has only one class ([1]). Metrics might be affected. Test indices: 10399-10422
# Warning iter 854: Test data has only one class ([1]). Metrics might be affected. Test indices: 10411-10434
# Warning iter 855: Test data has only one class ([1]). Metrics might be affected. Test indices: 10423-10446
# Warning iter 856: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
# Warning iter 857: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
# Warning iter 860: Test data has only one class ([1]). Metrics might be affected. Test indices: 10483-10506
#
# Iter 860/5000: Train Indices [10308:10482], Test Indices [10483:10506], Best Params Found: {'eta': 0.05, 'max_depth': 3, 'n_estimators': 100}
# Warning iter 864: Test data has only one class ([1]). Metrics might be affected. Test indices: 10531-10554
# Warning iter 880: Test data has only one class ([0]). Metrics might be affected. Test indices: 10723-10746
#
# Iter 880/5000: Train Indices [10548:10722], Test Indices [10723:10746], Best Params Found: {'eta': 0.05, 'max_depth': 3, 'n_estimators': 100}
# Warning iter 881: Test data has only one class ([0]). Metrics might be affected. Test indices: 10735-10758
# Warning iter 882: Test data has only one class ([0]). Metrics might be affected. Test indices: 10747-10770
# Warning iter 883: Test data has only one class ([0]). Metrics might be affected. Test indices: 10759-10782
# Warning iter 883: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
# Warning iter 884: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
# Warning iter 885: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
# Warning iter 891: Test data has only one class ([1]). Metrics might be affected. Test indices: 10855-10878
# Warning iter 892: Test data has only one class ([1]). Metrics might be affected. Test indices: 10867-10890
# Warning iter 894: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
# Warning iter 896: Test data has only one class ([0]). Metrics might be affected. Test indices: 10915-10938
# Warning iter 900: Test data has only one class ([1]). Metrics might be affected. Test indices: 10963-10986
#
# Iter 900/5000: Train Indices [10788:10962], Test Indices [10963:10986], Best Params Found: {'eta': 0.05, 'max_depth': 3, 'n_estimators': 100}
# Warning iter 908: Test data has only one class ([0]). Metrics might be affected. Test indices: 11059-11082
# Warning iter 912: Test data has only one class ([0]). Metrics might be affected. Test indices: 11107-11130
# Warning iter 920: Test data has only one class ([1]). Metrics might be affected. Test indices: 11203-11226
#
# Iter 920/5000: Train Indices [11028:11202], Test Indices [11203:11226], Best Params Found: {'eta': 0.05, 'max_depth': 4, 'n_estimators': 200}
# Warning iter 921: Test data has only one class ([1]). Metrics might be affected. Test indices: 11215-11238
# Warning iter 922: Test data has only one class ([1]). Metrics might be affected. Test indices: 11227-11250
# Warning iter 923: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
# Warning iter 924: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
# Warning iter 937: Test data has only one class ([0]). Metrics might be affected. Test indices: 11407-11430
# Warning iter 940: Test data has only one class ([1]). Metrics might be affected. Test indices: 11443-11466
#
# Iter 940/5000: Train Indices [11268:11442], Test Indices [11443:11466], Best Params Found: {'eta': 0.05, 'max_depth': 3, 'n_estimators': 100}
# Warning iter 941: Test data has only one class ([1]). Metrics might be affected. Test indices: 11455-11478
# Warning iter 943: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
# Warning iter 958: Test data has only one class ([0]). Metrics might be affected. Test indices: 11659-11682
#
# Iter 960/5000: Train Indices [11508:11682], Test Indices [11683:11706], Best Params Found: {'eta': 0.05, 'max_depth': 4, 'n_estimators': 100}
# Warning iter 963: Test data has only one class ([0]). Metrics might be affected. Test indices: 11719-11742
# Warning iter 964: Test data has only one class ([0]). Metrics might be affected. Test indices: 11731-11754
# Warning iter 965: Test data has only one class ([0]). Metrics might be affected. Test indices: 11743-11766
# Warning iter 966: Test data has only one class ([0]). Metrics might be affected. Test indices: 11755-11778
# Warning iter 966: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
# Warning iter 967: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
# Warning iter 968: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
# Warning iter 969: Test data has only one class ([0]). Metrics might be affected. Test indices: 11791-11814
# Warning iter 974: Test data has only one class ([0]). Metrics might be affected. Test indices: 11851-11874
# Warning iter 977: Test data has only one class ([1]). Metrics might be affected. Test indices: 11887-11910
# Warning iter 978: Test data has only one class ([1]). Metrics might be affected. Test indices: 11899-11922
# Warning iter 980: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
#
# Iter 980/5000: Train Indices [11748:11922], Test Indices [11923:11946], Best Params Found: {'eta': 0.05, 'max_depth': 3, 'n_estimators': 100}
# Warning iter 983: Test data has only one class ([0]). Metrics might be affected. Test indices: 11959-11982
# Warning iter 988: Test data has only one class ([0]). Metrics might be affected. Test indices: 12019-12042
# Warning iter 991: Test data has only one class ([1]). Metrics might be affected. Test indices: 12055-12078
# Warning iter 995: Test data has only one class ([1]). Metrics might be affected. Test indices: 12103-12126
#
# Iter 1000/5000: Train Indices [11988:12162], Test Indices [12163:12186], Best Params Found: {'eta': 0.05, 'max_depth': 3, 'n_estimators': 100}
# Warning iter 1008: Test data has only one class ([0]). Metrics might be affected. Test indices: 12259-12282
#
# Iter 1020/5000: Train Indices [12228:12402], Test Indices [12403:12426], Best Params Found: {'eta': 0.05, 'max_depth': 3, 'n_estimators': 100}
# Warning iter 1022: Test data has only one class ([0]). Metrics might be affected. Test indices: 12427-12450
# Warning iter 1023: Test data has only one class ([0]). Metrics might be affected. Test indices: 12439-12462
# Warning iter 1025: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
# Warning iter 1027: Test data has only one class ([1]). Metrics might be affected. Test indices: 12487-12510
# Warning iter 1028: Test data has only one class ([1]). Metrics might be affected. Test indices: 12499-12522
# Warning iter 1030: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
# Warning iter 1031: Test data has only one class ([1]). Metrics might be affected. Test indices: 12535-12558
#
# Iter 1040/5000: Train Indices [12468:12642], Test Indices [12643:12666], Best Params Found: {'eta': 0.1, 'max_depth': 3, 'n_estimators': 100}
# Warning iter 1042: Test data has only one class ([1]). Metrics might be affected. Test indices: 12667-12690
# Warning iter 1047: Test data has only one class ([1]). Metrics might be affected. Test indices: 12727-12750
# Warning iter 1053: Test data has only one class ([0]). Metrics might be affected. Test indices: 12799-12822
# Warning iter 1054: Test data has only one class ([0]). Metrics might be affected. Test indices: 12811-12834
# Warning iter 1055: Test data has only one class ([0]). Metrics might be affected. Test indices: 12823-12846
# Warning iter 1055: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
# Warning iter 1056: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
# Warning iter 1057: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
#
# Iter 1060/5000: Train Indices [12708:12882], Test Indices [12883:12906], Best Params Found: {'eta': 0.05, 'max_depth': 3, 'n_estimators': 100}
# Warning iter 1069: Test data has only one class ([0]). Metrics might be affected. Test indices: 12991-13014
# Warning iter 1075: Test data has only one class ([0]). Metrics might be affected. Test indices: 13063-13086
# Warning iter 1076: Test data has only one class ([0]). Metrics might be affected. Test indices: 13075-13098
# Warning iter 1078: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
#
# Iter 1080/5000: Train Indices [12948:13122], Test Indices [13123:13146], Best Params Found: {'eta': 0.05, 'max_depth': 3, 'n_estimators': 100}
# Warning iter 1081: Test data has only one class ([0]). Metrics might be affected. Test indices: 13135-13158
# Warning iter 1082: Test data has only one class ([0]). Metrics might be affected. Test indices: 13147-13170
# Warning iter 1084: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
# Warning iter 1087: Test data has only one class ([0]). Metrics might be affected. Test indices: 13207-13230
# Warning iter 1093: Test data has only one class ([1]). Metrics might be affected. Test indices: 13279-13302
# Warning iter 1097: Test data has only one class ([1]). Metrics might be affected. Test indices: 13327-13350
# Warning iter 1099: Test data has only one class ([0]). Metrics might be affected. Test indices: 13351-13374
# Warning iter 1100: Test data has only one class ([0]). Metrics might be affected. Test indices: 13363-13386
#
# Iter 1100/5000: Train Indices [13188:13362], Test Indices [13363:13386], Best Params Found: {'eta': 0.05, 'max_depth': 3, 'n_estimators': 100}
# Warning iter 1102: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
# Warning iter 1118: Test data has only one class ([0]). Metrics might be affected. Test indices: 13579-13602
# Warning iter 1119: Test data has only one class ([0]). Metrics might be affected. Test indices: 13591-13614
#
# Iter 1120/5000: Train Indices [13428:13602], Test Indices [13603:13626], Best Params Found: {'eta': 0.05, 'max_depth': 3, 'n_estimators': 100}
# Warning iter 1121: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
# Warning iter 1124: Test data has only one class ([1]). Metrics might be affected. Test indices: 13651-13674
# Warning iter 1127: Test data has only one class ([0]). Metrics might be affected. Test indices: 13687-13710
# Warning iter 1132: Test data has only one class ([0]). Metrics might be affected. Test indices: 13747-13770
# Warning iter 1133: Test data has only one class ([0]). Metrics might be affected. Test indices: 13759-13782
# Warning iter 1135: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
#
# Iter 1140/5000: Train Indices [13668:13842], Test Indices [13843:13866], Best Params Found: {'eta': 0.05, 'max_depth': 3, 'n_estimators': 100}
# Warning iter 1143: Test data has only one class ([1]). Metrics might be affected. Test indices: 13879-13902
# Warning iter 1146: Test data has only one class ([0]). Metrics might be affected. Test indices: 13915-13938
# Warning iter 1147: Test data has only one class ([0]). Metrics might be affected. Test indices: 13927-13950
# ...
# Warning iter 4647: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
# Warning iter 4648: Test data has only one class ([0]). Metrics might be affected. Test indices: 55939-55962
# Warning iter 4648: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
# Warning iter 4649: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
# Warning iter 4650: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
# Warning iter 4656: Test data has only one class ([1]). Metrics might be affected. Test indices: 56035-56058
#
# Iter 4660/5000: Train Indices [55908:56082], Test Indices [56083:56106], Best Params Found: {'eta': 0.05, 'max_depth': 3, 'n_estimators': 100}
# Warning iter 4664: Test data has only one class ([1]). Metrics might be affected. Test indices: 56131-56154
# Warning iter 4670: Test data has only one class ([0]). Metrics might be affected. Test indices: 56203-56226
# Warning iter 4673: Test data has only one class ([0]). Metrics might be affected. Test indices: 56239-56262
# Warning iter 4676: Test data has only one class ([1]). Metrics might be affected. Test indices: 56275-56298
#
# Iter 4680/5000: Train Indices [56148:56322], Test Indices [56323:56346], Best Params Found: {'eta': 0.05, 'max_depth': 3, 'n_estimators': 100}
# Warning iter 4683: Test data has only one class ([1]). Metrics might be affected. Test indices: 56359-56382
# Warning iter 4684: Test data has only one class ([1]). Metrics might be affected. Test indices: 56371-56394
# Warning iter 4685: Test data has only one class ([1]). Metrics might be affected. Test indices: 56383-56406
# Warning iter 4686: Test data has only one class ([1]). Metrics might be affected. Test indices: 56395-56418
# Warning iter 4686: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
# Warning iter 4687: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
# Warning iter 4688: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
#
# Iter 4700/5000: Train Indices [56388:56562], Test Indices [56563:56586], Best Params Found: {'eta': 0.05, 'max_depth': 3, 'n_estimators': 100}
# Warning iter 4701: Test data has only one class ([1]). Metrics might be affected. Test indices: 56575-56598
# Warning iter 4710: Test data has only one class ([1]). Metrics might be affected. Test indices: 56683-56706
# Warning iter 4711: Test data has only one class ([1]). Metrics might be affected. Test indices: 56695-56718
# Warning iter 4712: Test data has only one class ([1]). Metrics might be affected. Test indices: 56707-56730
# Warning iter 4712: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
# Warning iter 4713: Test data has only one class ([1]). Metrics might be affected. Test indices: 56719-56742
# Warning iter 4713: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
# Warning iter 4714: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
# Warning iter 4715: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
#
# Iter 4720/5000: Train Indices [56628:56802], Test Indices [56803:56826], Best Params Found: {'eta': 0.05, 'max_depth': 3, 'n_estimators': 100}
# Warning iter 4731: Test data has only one class ([1]). Metrics might be affected. Test indices: 56935-56958
# Warning iter 4732: Test data has only one class ([1]). Metrics might be affected. Test indices: 56947-56970
# Warning iter 4733: Test data has only one class ([1]). Metrics might be affected. Test indices: 56959-56982
# Warning iter 4734: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
# Warning iter 4735: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
# Warning iter 4737: Test data has only one class ([0]). Metrics might be affected. Test indices: 57007-57030
#
# Iter 4740/5000: Train Indices [56868:57042], Test Indices [57043:57066], Best Params Found: {'eta': 0.05, 'max_depth': 3, 'n_estimators': 100}
# Warning iter 4741: Test data has only one class ([0]). Metrics might be affected. Test indices: 57055-57078
# Warning iter 4759: Test data has only one class ([1]). Metrics might be affected. Test indices: 57271-57294
#
# Iter 4760/5000: Train Indices [57108:57282], Test Indices [57283:57306], Best Params Found: {'eta': 0.05, 'max_depth': 3, 'n_estimators': 100}
# Warning iter 4768: Test data has only one class ([0]). Metrics might be affected. Test indices: 57379-57402
# Warning iter 4771: Test data has only one class ([1]). Metrics might be affected. Test indices: 57415-57438
# Warning iter 4772: Test data has only one class ([1]). Metrics might be affected. Test indices: 57427-57450
# Warning iter 4774: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
# Warning iter 4780: Test data has only one class ([1]). Metrics might be affected. Test indices: 57523-57546
#
# Iter 4780/5000: Train Indices [57348:57522], Test Indices [57523:57546], Best Params Found: {'eta': 0.05, 'max_depth': 3, 'n_estimators': 100}
# Warning iter 4781: Test data has only one class ([1]). Metrics might be affected. Test indices: 57535-57558
# Warning iter 4782: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
# Warning iter 4783: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
# Warning iter 4785: Test data has only one class ([0]). Metrics might be affected. Test indices: 57583-57606
# Warning iter 4786: Test data has only one class ([0]). Metrics might be affected. Test indices: 57595-57618
# Warning iter 4787: Test data has only one class ([0]). Metrics might be affected. Test indices: 57607-57630
# Warning iter 4788: Test data has only one class ([0]). Metrics might be affected. Test indices: 57619-57642
# Warning iter 4788: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
# Warning iter 4789: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
# Warning iter 4790: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
# Warning iter 4793: Test data has only one class ([0]). Metrics might be affected. Test indices: 57679-57702
# Warning iter 4794: Test data has only one class ([0]). Metrics might be affected. Test indices: 57691-57714
# Warning iter 4796: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
#
# Iter 4800/5000: Train Indices [57588:57762], Test Indices [57763:57786], Best Params Found: {'eta': 0.05, 'max_depth': 3, 'n_estimators': 100}
# Warning iter 4801: Test data has only one class ([0]). Metrics might be affected. Test indices: 57775-57798
# Warning iter 4814: Test data has only one class ([1]). Metrics might be affected. Test indices: 57931-57954
# Warning iter 4815: Test data has only one class ([1]). Metrics might be affected. Test indices: 57943-57966
# Warning iter 4817: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
#
# Iter 4820/5000: Train Indices [57828:58002], Test Indices [58003:58026], Best Params Found: {'eta': 0.05, 'max_depth': 3, 'n_estimators': 100}
# Warning iter 4823: Test data has only one class ([1]). Metrics might be affected. Test indices: 58039-58062
# Warning iter 4826: Test data has only one class ([0]). Metrics might be affected. Test indices: 58075-58098
# Warning iter 4827: Test data has only one class ([0]). Metrics might be affected. Test indices: 58087-58110
# Warning iter 4828: Test data has only one class ([0]). Metrics might be affected. Test indices: 58099-58122
# Warning iter 4829: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
# Warning iter 4830: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
# Warning iter 4839: Test data has only one class ([1]). Metrics might be affected. Test indices: 58231-58254
#
# Iter 4840/5000: Train Indices [58068:58242], Test Indices [58243:58266], Best Params Found: {'eta': 0.1, 'max_depth': 3, 'n_estimators': 100}
# Warning iter 4845: Test data has only one class ([1]). Metrics might be affected. Test indices: 58303-58326
#
# Iter 4860/5000: Train Indices [58308:58482], Test Indices [58483:58506], Best Params Found: {'eta': 0.1, 'max_depth': 3, 'n_estimators': 100}
# Warning iter 4864: Test data has only one class ([0]). Metrics might be affected. Test indices: 58531-58554
# Warning iter 4870: Test data has only one class ([1]). Metrics might be affected. Test indices: 58603-58626
# Warning iter 4873: Test data has only one class ([0]). Metrics might be affected. Test indices: 58639-58662
# Warning iter 4874: Test data has only one class ([0]). Metrics might be affected. Test indices: 58651-58674
# Warning iter 4875: Test data has only one class ([0]). Metrics might be affected. Test indices: 58663-58686
# Warning iter 4876: Test data has only one class ([0]). Metrics might be affected. Test indices: 58675-58698
# Warning iter 4876: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
# Warning iter 4877: Test data has only one class ([0]). Metrics might be affected. Test indices: 58687-58710
# Warning iter 4877: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
# Warning iter 4878: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
# Warning iter 4879: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
#
# Iter 4880/5000: Train Indices [58548:58722], Test Indices [58723:58746], Best Params Found: {'eta': 0.05, 'max_depth': 3, 'n_estimators': 100}
# Warning iter 4882: Test data has only one class ([0]). Metrics might be affected. Test indices: 58747-58770
# Warning iter 4893: Test data has only one class ([1]). Metrics might be affected. Test indices: 58879-58902
#
# Iter 4900/5000: Train Indices [58788:58962], Test Indices [58963:58986], Best Params Found: {'eta': 0.05, 'max_depth': 3, 'n_estimators': 100}
# Warning iter 4901: Test data has only one class ([1]). Metrics might be affected. Test indices: 58975-58998
# Warning iter 4905: Test data has only one class ([0]). Metrics might be affected. Test indices: 59023-59046
# Warning iter 4906: Test data has only one class ([0]). Metrics might be affected. Test indices: 59035-59058
# Warning iter 4907: Test data has only one class ([0]). Metrics might be affected. Test indices: 59047-59070
# Warning iter 4908: Test data has only one class ([0]). Metrics might be affected. Test indices: 59059-59082
# Warning iter 4908: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
# Warning iter 4909: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
# Warning iter 4910: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
# Warning iter 4912: Test data has only one class ([1]). Metrics might be affected. Test indices: 59107-59130
# Warning iter 4913: Test data has only one class ([1]). Metrics might be affected. Test indices: 59119-59142
# Warning iter 4915: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
# Warning iter 4916: Test data has only one class ([0]). Metrics might be affected. Test indices: 59155-59178
# Warning iter 4920: Test data has only one class ([0]). Metrics might be affected. Test indices: 59203-59226
#
# Iter 4920/5000: Train Indices [59028:59202], Test Indices [59203:59226], Best Params Found: {'eta': 0.05, 'max_depth': 3, 'n_estimators': 100}
# Warning iter 4921: Test data has only one class ([0]). Metrics might be affected. Test indices: 59215-59238
# Warning iter 4922: Test data has only one class ([0]). Metrics might be affected. Test indices: 59227-59250
# Warning iter 4923: Test data has only one class ([0]). Metrics might be affected. Test indices: 59239-59262
# Warning iter 4923: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
# Warning iter 4924: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
# Warning iter 4925: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
# Warning iter 4933: Test data has only one class ([1]). Metrics might be affected. Test indices: 59359-59382
# Warning iter 4936: Test data has only one class ([0]). Metrics might be affected. Test indices: 59395-59418
# Warning iter 4938: Test data has only one class ([1]). Metrics might be affected. Test indices: 59419-59442
# Warning iter 4939: Test data has only one class ([1]). Metrics might be affected. Test indices: 59431-59454
#
# Iter 4940/5000: Train Indices [59268:59442], Test Indices [59443:59466], Best Params Found: {'eta': 0.05, 'max_depth': 3, 'n_estimators': 100}
# Warning iter 4941: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
# Warning iter 4947: Test data has only one class ([0]). Metrics might be affected. Test indices: 59527-59550
# Warning iter 4948: Test data has only one class ([0]). Metrics might be affected. Test indices: 59539-59562
# Warning iter 4949: Test data has only one class ([0]). Metrics might be affected. Test indices: 59551-59574
# Warning iter 4950: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
# Warning iter 4951: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
#
# Iter 4960/5000: Train Indices [59508:59682], Test Indices [59683:59706], Best Params Found: {'eta': 0.1, 'max_depth': 3, 'n_estimators': 100}
# Warning iter 4976: Test data has only one class ([1]). Metrics might be affected. Test indices: 59875-59898
#
# Iter 4980/5000: Train Indices [59748:59922], Test Indices [59923:59946], Best Params Found: {'eta': 0.05, 'max_depth': 3, 'n_estimators': 100}
# Warning iter 4984: Test data has only one class ([0]). Metrics might be affected. Test indices: 59971-59994
# Warning iter 4985: Test data has only one class ([0]). Metrics might be affected. Test indices: 59983-60006
# Warning iter 4986: Test data has only one class ([0]). Metrics might be affected. Test indices: 59995-60018
# Warning iter 4987: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
# Warning iter 4988: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
# Warning iter 4992: Test data has only one class ([1]). Metrics might be affected. Test indices: 60067-60090
# Warning iter 4993: Test data has only one class ([1]). Metrics might be affected. Test indices: 60079-60102
# Warning iter 4995: Inner train (2 classes) or validation set (1 classes) has only one class. Skipping inner CV.
#
# Iter 5000/5000: Train Indices [59988:60162], Test Indices [60163:60186], Best Params Found: {'eta': 0.05, 'max_depth': 3, 'n_estimators': 100}
#
# Stopping: Test window end index (60199) exceeds total rows (60188).
# ------------------------------
# Walk-Forward Validation finished in 4162.17 seconds (69.37 minutes).
#
# --- 6. Final Results ---
#
# --- Average Walk-Forward Validation Results (XGBoost with Inner CV) ---
# Total Folds / Successful Iterations Evaluated: 5000
# Target Threshold: 0.1% increase over 24 hours
# Train Window: 175 hours, Test Window: 24 hours, Step: 12 hours
# Average Accuracy:  0.6020
# Average Precision: 0.5407 (for class 1: return >= 0.1%)
# Average Recall:    0.5456 (for class 1: return >= 0.1%)
# Average F1-Score:  0.4596 (for class 1: return >= 0.1%)
#
# --- Standard Deviation of Metrics Across Folds ---
# Std Dev Accuracy:  0.2599
# Std Dev Precision: 0.4110
# Std Dev Recall:    0.4118
# Std Dev F1-Score:  0.3472
#
# Script finished.

# %% [markdown]
# Computational Overhead: This adds a substantial calculation step before every single training iteration. At a 5-minute retraining frequency, calculating weighted importances across 100 past results, selecting features, and subsetting the data adds significant time and complexity to each cycle. This might make keeping up with the 5-minute interval difficult.
