# %% [markdown]
# Walk-Forward Validation / Rolling Forecast Origin

# %% [markdown]
# General Hierarchy of Hyperparameter Importance (often, but context matters):
#
# 1. eta (learning_rate) & n_estimators: These are highly impactful and strongly linked. Lower eta generally requires higher n_estimators for convergence. Finding a good balance is crucial for performance.
# 2. max_depth: Controls the complexity of individual trees. Very important for preventing overfitting/underfitting.
# 3. subsample & colsample_bytree (or _bylevel, _bynode): Introduce stochasticity, reducing variance and preventing overfitting. Often provide good gains.
# 4. min_child_weight: Acts as a regularizer, particularly useful on imbalanced datasets to prevent trees from focusing too much on single outlier instances of the minority class.
# 5. gamma (min_split_loss): Another regularization parameter, controlling whether a split is made based on loss reduction.
# 6. Regularization (lambda, alpha): L2 and L1 regularization help prevent overfitting by shrinking weights. They are important, but often fine-tuning them yields smaller gains compared to getting the core structure (max_depth, eta/n_estimators) right, unless you have severe overfitting issues.

# %% [markdown]
# Here are typical considerations for fixed values:
#
# 1. gamma (min_split_loss):
# Purpose: Controls the minimum loss reduction needed to make a split. Higher values lead to fewer splits (more conservative).
# Default: 0 (allows any split that reduces loss, even slightly).
# Typical Fixed Value: 0. Sticking with the default is very common if you are not tuning it. It allows the tree to grow based purely on loss improvement.
# Slightly More Conservative Fixed Value: Sometimes people might use a very small value like 0.1 or 0.2 if they want to introduce a tiny barrier against splitting on minimal gains, but usually, it's kept at 0 unless tuned.
# Range Idea: Think 0 to ~1 as the area of most impact; values much larger quickly prune the tree heavily.
#
# 2. lambda (reg_lambda / L2 Regularization):
# Purpose: Penalizes large weights using the square of their magnitude. Encourages smaller, more distributed weights, good for preventing overfitting when features might be correlated.
# Default: 1. This already provides a moderate amount of L2 regularization.
# Typical Fixed Value: 1. The default is a very sensible starting point and often used as the fixed value.
# Alternative Moderate Fixed Values: Values between 0.5 and 2 are generally considered moderate L2 regularization. You could fix it at 1.5 (like you had) or 1 without drastically changing the regularization strength compared to the default.
# Range Idea: 0 means no L2. Values from 0.1 to 10 cover a wide range from weak to strong regularization.
#
# 3. alpha (reg_alpha / L1 Regularization):
# Purpose: Penalizes large weights using their absolute magnitude. Can drive feature weights to exactly zero, performing implicit feature selection.
# Default: 0 (no L1 regularization).
# Typical Fixed Value: 0. If you don't have a specific reason to encourage sparsity or perform L1 feature selection, leaving it at the default is standard practice.
# Slightly More Conservative Fixed Value: If you suspect some L1 might help a little without tuning, a very small value like 0.01 or 0.1 might be chosen. But often, if L1 is desired, it's added to the tuning grid.
# Range Idea: Similar to lambda, 0 means no L1, and values from 0.1 to 10 cover weak to strong L1 effects.
#
# Summary for Fixed Values (when not tuning):
#
# Most Common / Standard Defaults:
#
# gamma: 0
# lambda: 1
# alpha: 0
#
# Slightly Modified Defaults (if desired):
#
# gamma: 0 or 0.1
# lambda: 1 or 1.5
# alpha: 0 or 0.1

# %%
import os
import pandas as pd
import numpy as np
from sqlalchemy import create_engine, text
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, log_loss
from sklearn.model_selection import ParameterGrid
from sklearn.exceptions import UndefinedMetricWarning
import time
import warnings # Make sure this is imported

# --- Suppress Warnings ---
# Suppress UndefinedMetricWarning (when precision/recall/F1 is 0)
warnings.filterwarnings("ignore", category=UndefinedMetricWarning)
# Suppress potential future warnings from xgboost itself
warnings.filterwarnings("ignore", category=FutureWarning, module='xgboost')
# Suppress the specific 'use_label_encoder' UserWarning from xgboost's sklearn wrapper
warnings.filterwarnings("ignore", category=UserWarning, module='xgboost.sklearn')

# --- Constants and Configuration ---
DB_CONNECTION = os.getenv('DB_CONNECTION', 'postgresql+psycopg2://postgres:bubZ$tep433@localhost:5432/ohlcv_db')
TARGET_THRESHOLD_PCT = 0.1 # <<< Target threshold percentage variable
SQL_LIMIT = None # Set to an integer (e.g., 5000) for testing, None for full run

# Walk-forward params
TRAIN_WINDOW_HOURS = 3
TEST_WINDOW_HOURS = 1
STEP_MINUTES = 2

# Convert time durations to rows (assuming 1 row per minute)
TRAIN_WINDOW_ROWS = TRAIN_WINDOW_HOURS * 60
TEST_WINDOW_ROWS = TEST_WINDOW_HOURS * 60
STEP_ROWS = STEP_MINUTES

# --- Simple Grid Search Configuration ---
# Define a *small* grid of parameters to search within each window
# Keep this very limited to control compute time!
INNER_CV_PARAM_GRID = {
    'max_depth': [3, 5],          # Test a shallow and slightly deeper tree
    'n_estimators': [150, 350],   # Test fewer/more trees
    'eta': [0.04, 0.12],          # Optionally test learning rate, but adds more combos
    'subsample': [0.8, 1.0],
    'alpha': [0.3, 0.7],
    'min_child_weight': [2, 5]
}
# Size of the validation set taken from the *end* of the training window (%)
INNER_CV_VALIDATION_PCT = 0.20 # Use last 20% of training data for quick validation

# Fixed XGBoost parameters (not tuned in the inner loop)
XGB_FIXED_PARAMS = {
    'objective': 'binary:logistic',
    'eval_metric': 'logloss',    # Often used for XGBoost internal evaluation
    # Fixed learning rate (unless added to grid)
    #'subsample': 0.8,
    'colsample_bytree': 0.8,
    #'min_child_weight': 1,
    'gamma': 0.05,
    'lambda': 3,               # L2 regularization
    #'alpha': 0.8,                # L1 regularization
    'random_state': 42,
    'n_jobs': -1,
    # Optional GPU Acceleration:
    'tree_method': 'gpu_hist',
    'predictor': 'gpu_predictor'
}


# --- 1. Data Loading and Initial Setup ---
print("--- 1. Data Loading ---")
try:
    engine = create_engine(DB_CONNECTION)
except Exception as e:
    print(f"Error creating database engine: {e}")
    exit()

# Define the feature columns to fetch
feature_columns_db = [ # Same list as before...
    'timestamp', 'symbol', 'open', 'high', 'low', 'close', 'volume_btc', 'volume_usd',
    'garman_klass_12h', 'price_range_pct', 'oc_change_pct', 'parkinson_3h',
    'ma_3h', 'rolling_std_3h', 'lag_3h_price_return', 'lag_6h_price_return',
    'lag_12h_price_return', 'lag_24h_price_return', 'lag_48h_price_return',
    'lag_72h_price_return', 'lag_168h_price_return', 'volume_return_1h',
    'lag_3h_volume_return', 'lag_6h_volume_return', 'lag_12h_volume_return',
    'lag_24h_volume_return', 'ma_6h', 'ma_12h', 'ma_24h', 'ma_48h', 'ma_72h',
    'ma_168h', 'rolling_std_6h', 'rolling_std_12h', 'rolling_std_24h',
    'rolling_std_48h', 'rolling_std_72h', 'rolling_std_168h', 'atr_14h',
    'atr_24h', 'atr_48h', 'close_div_ma_24h', 'close_div_ma_48h',
    'close_div_ma_168h', 'ma12_div_ma48', 'ma24_div_ma168', 'std12_div_std72',
    'volume_btc_x_range', 'rolling_std_3h_sq', 'price_return_1h_sq',
    'rolling_std_12h_sqrt',
    'hour_0', 'hour_1', 'hour_2', 'hour_3', 'hour_4', 'hour_5', 'hour_6',
    'hour_7', 'hour_8', 'hour_9', 'hour_10', 'hour_11', 'hour_12',
    'hour_13', 'hour_14', 'hour_15', 'hour_16', 'hour_17', 'hour_18',
    'hour_19', 'hour_20', 'hour_21', 'hour_22', 'hour_23',
    'day_0', 'day_1', 'day_2', 'day_3', 'day_4', 'day_5', 'day_6',
    'rsi_14h', 'macd', 'macd_signal', 'macd_hist', 'volume_ma_12h',
    'volume_ma_24h', 'volume_ma_72h', 'volume_ma_168h', 'volume_div_ma_24h',
    'obv', 'obv_ma_24h', 'atr_14_div_atr_48', 'stoch_k', 'stoch_d',
    'z_score_24h', 'rolling_skew_24h', 'rolling_kurt_24h',
    'adx_14h', 'plus_di_14h', 'minus_di_14h', 'ad_line', 'cmf_20h', 'cci_20h',
    'bband_width_20h', 'bband_pctb_20h', 'close_pos_in_range',
    'vwap_24h', 'log_return_1h', 'stoch_rsi_k', 'stoch_rsi_d'
]
columns_str = ', '.join(f'"{col}"' for col in feature_columns_db)
query = f"SELECT {columns_str} FROM public.advanced_features ORDER BY timestamp ASC"
if SQL_LIMIT:
    query += f" LIMIT {SQL_LIMIT}"

try:
    print(f"Fetching data (limit={SQL_LIMIT})...")
    fetch_start_time = time.time()
    df_raw = pd.read_sql(query, engine)
    fetch_end_time = time.time()
    print(f"Data loaded. Shape: {df_raw.shape}. Time: {fetch_end_time - fetch_start_time:.2f}s")
    df_raw['timestamp'] = pd.to_datetime(df_raw['timestamp'])
    print("\nRaw Dataset Information:")
    if not df_raw.empty:
        print(f"Time range: {df_raw['timestamp'].min()} to {df_raw['timestamp'].max()}")
        print(f"Symbols: {df_raw['symbol'].unique()}")
    else:
        print("DataFrame is empty after fetching.")
        exit()
except Exception as e:
    print(f"Error loading data: {e}")
    exit()

# --- 2. Data Cleaning ---
print("\n--- 2. Data Cleaning ---")
numeric_columns = df_raw.select_dtypes(include=np.number).columns
missing_before = df_raw[numeric_columns].isna().sum().sum()
infinite_before = np.isinf(df_raw[numeric_columns].values).sum()
print(f"Missing/Infinite before: {missing_before} / {infinite_before}")
df = df_raw.replace([np.inf, -np.inf], np.nan).dropna(subset=numeric_columns)
missing_after = df[numeric_columns].isna().sum().sum()
infinite_after = np.isinf(df[numeric_columns].values).sum()
print(f"Missing/Infinite after: {missing_after} / {infinite_after}")
print(f"Rows removed: {len(df_raw) - len(df)} ({((len(df_raw) - len(df)) / len(df_raw) * 100):.2f}%)")
if df.empty: print("DataFrame empty after cleaning."); exit()

# --- 3. Feature Engineering ---
print("\n--- 3. Feature Engineering ---")
# Dummy encode symbols
print("Creating dummy variables for symbols (BTC, SOL)...")
df['BTC'] = (df['symbol'] == 'BTC').astype(int)
df['SOL'] = (df['symbol'] == 'SOL').astype(int)

# Create binary target
print(f"Creating binary target 'target' (1-hour return >= {TARGET_THRESHOLD_PCT}%)...")
# Ensure shift happens correctly within each group
df = df.sort_values(['symbol', 'timestamp']) # Sort for reliable shift within groups
df['future_price'] = df.groupby('symbol')['close'].shift(-TEST_WINDOW_ROWS) # Shift by test window size (60 rows)
df['price_return_1h'] = (df['future_price'] - df['close']) / df['close'] * 100
df['target'] = (df['price_return_1h'] >= TARGET_THRESHOLD_PCT).astype(int)
df = df.drop(['future_price', 'price_return_1h'], axis=1)
print(f"NaN values in target before drop: {df['target'].isna().sum()}")
df = df.dropna(subset=['target'])
print(f"Rows after removing NaN targets: {len(df)}")
if df.empty: print("DataFrame empty after target creation."); exit()

# Display target distribution
target_counts = df['target'].value_counts()
print("\nTarget variable distribution:")
print(f"  0 (< {TARGET_THRESHOLD_PCT}% return): {target_counts.get(0, 0)} ({target_counts.get(0, 0) / len(df) * 100:.2f}%)")
print(f"  1 (>= {TARGET_THRESHOLD_PCT}% return): {target_counts.get(1, 0)} ({target_counts.get(1, 0) / len(df) * 100:.2f}%)")

# --- 4. Final Preparation for Walk-Forward ---
print("\n--- 4. Final Preparation ---")
df = df.sort_values('timestamp') # Sort chronologically overall
df = df.reset_index(drop=True) # Reset index for iloc
print(f"Final DataFrame shape for backtesting: {df.shape}")

TARGET_COLUMN = 'target'
EXCLUDE_COLS = [TARGET_COLUMN, 'symbol', 'timestamp']
FEATURE_COLUMNS = [col for col in df.columns if col not in EXCLUDE_COLS]
print(f"\n--- Feature Selection ---")
print(f"Target Column: '{TARGET_COLUMN}'")
print(f"Number of features selected: {len(FEATURE_COLUMNS)}")
print(f"  - 'BTC' included: {'BTC' in FEATURE_COLUMNS}")
print(f"  - 'SOL' included: {'SOL' in FEATURE_COLUMNS}")

# --- 5. Walk-Forward Validation Implementation ---
print("\n--- 5. Starting Walk-Forward Validation ---")
all_metrics = {'accuracy': [], 'precision': [], 'recall': [], 'f1': []}
iteration_count = 0
n_rows_total = len(df)
current_train_start_idx = 0
total_iterations_estimate = max(0, (n_rows_total - TRAIN_WINDOW_ROWS - TEST_WINDOW_ROWS) // STEP_ROWS)
print(f"Total rows: {n_rows_total}, Train: {TRAIN_WINDOW_ROWS}, Test: {TEST_WINDOW_ROWS}, Step: {STEP_ROWS}")
print(f"Estimated iterations: {total_iterations_estimate}")
print(f"Inner CV Grid: {INNER_CV_PARAM_GRID}")
print("-" * 30)
start_loop_time = time.time()

while True:
    # --- Define Window Boundaries ---
    train_end_idx = current_train_start_idx + TRAIN_WINDOW_ROWS
    test_start_idx = train_end_idx
    test_end_idx = test_start_idx + TEST_WINDOW_ROWS

    # --- Boundary Checks ---
    if test_end_idx > n_rows_total:
        print(f"\nStopping: Test window end index ({test_end_idx}) > total rows ({n_rows_total}).")
        break

    # --- Data Slicing ---
    train_df = df.iloc[current_train_start_idx : train_end_idx]
    test_df = df.iloc[test_start_idx : test_end_idx]

    # --- Data Validity Checks ---
    min_train_samples = 50
    min_test_samples = 5
    if len(train_df) < min_train_samples or len(test_df) < min_test_samples:
         print(f"Skipping iter {iteration_count + 1}: Insufficient data train ({len(train_df)}) or test ({len(test_df)}).")
         current_train_start_idx += STEP_ROWS
         continue

    X_train_full = train_df[FEATURE_COLUMNS]
    y_train_full = train_df[TARGET_COLUMN]
    X_test = test_df[FEATURE_COLUMNS]
    y_test = test_df[TARGET_COLUMN]

    # --- Check for Single Class in Full Train/Test ---
    train_counts = y_train_full.value_counts()
    test_counts = y_test.value_counts()
    if len(train_counts) < 2:
        print(f"Skipping iter {iteration_count + 1}: Full training data has only one class ({train_counts.index.tolist()}).")
        current_train_start_idx += STEP_ROWS
        continue
    if len(test_counts) < 2:
         print(f"Warning iter {iteration_count + 1}: Test data has only one class ({test_counts.index.tolist()}). Metrics might be affected.")

    # --- Calculate scale_pos_weight (based on full training data) ---
    neg_count = train_counts.get(0, 0)
    pos_count = train_counts.get(1, 0)
    scale_pos_weight_val = neg_count / pos_count if pos_count > 0 else 1.0

    # --- Inner Loop: Simple Grid Search ---
    iter_start_time = time.time()
    best_val_score = -np.inf # Initialize for maximization (e.g., F1) or np.inf for minimization (e.g., logloss)
    best_params_iter = None

    # Split training data for inner validation
    val_size = int(len(X_train_full) * INNER_CV_VALIDATION_PCT)
    if val_size < min_test_samples: # Ensure validation set is usable
        print(f"Warning iter {iteration_count + 1}: Validation set too small ({val_size}), skipping inner CV.")
        best_params_iter = list(ParameterGrid(INNER_CV_PARAM_GRID))[0] # Use first combo as default
    else:
        X_train_sub = X_train_full[:-val_size]
        y_train_sub = y_train_full[:-val_size]
        X_val = X_train_full[-val_size:]
        y_val = y_train_full[-val_size:]

        # Check if validation sub-set has both classes
        if len(y_val.unique()) < 2:
            print(f"Warning iter {iteration_count + 1}: Validation set has only one class, skipping inner CV.")
            best_params_iter = list(ParameterGrid(INNER_CV_PARAM_GRID))[0] # Use first combo
        else:
            # Iterate through the small grid
            for params_cv in ParameterGrid(INNER_CV_PARAM_GRID):
                try:
                    # Combine fixed and CV params
                    current_cv_params = {**XGB_FIXED_PARAMS, **params_cv}

                    model_cv = XGBClassifier(**current_cv_params,
                                             scale_pos_weight=scale_pos_weight_val, # Use weight calculated on full train set
                                             use_label_encoder=False)

                    model_cv.fit(X_train_sub, y_train_sub,
                                 eval_set=[(X_val, y_val)], # Optional: use early stopping
                                 early_stopping_rounds=10, # Stop if val score doesn't improve for 10 rounds
                                 verbose=False) # Suppress CV training verbosity

                    y_pred_val = model_cv.predict(X_val)
                    # Use F1 score on validation set - good for imbalance
                    val_score = f1_score(y_val, y_pred_val, average='binary', pos_label=1, zero_division=0)

                    if val_score > best_val_score:
                        best_val_score = val_score
                        best_params_iter = params_cv

                except Exception as e_cv:
                     print(f"Error during inner CV iter {iteration_count + 1} with params {params_cv}: {e_cv}")
                     # If error occurs, maybe default to first param set or skip CV for this iteration
                     if best_params_iter is None:
                         best_params_iter = list(ParameterGrid(INNER_CV_PARAM_GRID))[0]


    # Handle case where inner CV failed entirely or was skipped
    if best_params_iter is None:
        print(f"Warning iter {iteration_count + 1}: Inner CV did not find best params, using default.")
        best_params_iter = list(ParameterGrid(INNER_CV_PARAM_GRID))[0] # Default to first combo

    # --- Train Final Model for this Iteration ---
    # Combine fixed and best CV params found
    final_iter_params = {**XGB_FIXED_PARAMS, **best_params_iter}

    # Display progress less frequently
    if (iteration_count == 0) or ((iteration_count + 1) % 50 == 0) or (test_end_idx > n_rows_total):
         print(f"\nIter {iteration_count + 1}/{total_iterations_estimate}: Train[{current_train_start_idx}:{train_end_idx-1}], Test[{test_start_idx}:{test_end_idx-1}], Best Params: {best_params_iter}")

    current_model = XGBClassifier(**final_iter_params,
                                  scale_pos_weight=scale_pos_weight_val,
                                  use_label_encoder=False)

    # Train on the FULL training set for this window
    current_model.fit(X_train_full, y_train_full, verbose=False)

    # --- Prediction and Evaluation ---
    y_pred = current_model.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred, average='binary', pos_label=1, zero_division=0)
    recall = recall_score(y_test, y_pred, average='binary', pos_label=1, zero_division=0)
    f1 = f1_score(y_test, y_pred, average='binary', pos_label=1, zero_division=0)

    all_metrics['accuracy'].append(accuracy)
    all_metrics['precision'].append(precision)
    all_metrics['recall'].append(recall)
    all_metrics['f1'].append(f1)

    iteration_count += 1
    iter_end_time = time.time()
    # Optional: print metrics per iteration
    # print(f"  Metrics: Acc={accuracy:.4f}, Prc={precision:.4f}, Rec={recall:.4f}, F1={f1:.4f} (took {iter_end_time - iter_start_time:.2f}s)")

    # --- Move to Next Window ---
    current_train_start_idx += STEP_ROWS

end_loop_time = time.time()
print("-" * 30)
loop_duration_minutes = (end_loop_time - start_loop_time) / 60
print(f"Walk-Forward Validation finished in {end_loop_time - start_loop_time:.2f} seconds ({loop_duration_minutes:.2f} minutes).")

# --- 6. Aggregate and Display Results ---
print("\n--- 6. Final Results ---")
if iteration_count > 0:
    avg_accuracy = np.mean(all_metrics['accuracy'])
    avg_precision = np.mean(all_metrics['precision'])
    avg_recall = np.mean(all_metrics['recall'])
    avg_f1 = np.mean(all_metrics['f1'])

    print("\n--- Average Walk-Forward Validation Results (XGBoost with Inner CV) ---")
    print(f"Total Folds / Iterations Evaluated: {iteration_count}")
    print(f"Target Threshold: {TARGET_THRESHOLD_PCT}%")
    print(f"Average Accuracy:  {avg_accuracy:.4f}")
    print(f"Average Precision: {avg_precision:.4f} (for class 1: return >= {TARGET_THRESHOLD_PCT}%)")
    print(f"Average Recall:    {avg_recall:.4f} (for class 1: return >= {TARGET_THRESHOLD_PCT}%)")
    print(f"Average F1-Score:  {avg_f1:.4f} (for class 1: return >= {TARGET_THRESHOLD_PCT}%)")

    std_accuracy = np.std(all_metrics['accuracy'])
    std_precision = np.std(all_metrics['precision'])
    std_recall = np.std(all_metrics['recall'])
    std_f1 = np.std(all_metrics['f1'])
    print("\n--- Standard Deviation of Metrics Across Folds ---")
    print(f"Std Dev Accuracy:  {std_accuracy:.4f}")
    print(f"Std Dev Precision: {std_precision:.4f}")
    print(f"Std Dev Recall:    {std_recall:.4f}")
    print(f"Std Dev F1-Score:  {std_f1:.4f}")
else:
    print("\nNo iterations were successfully completed.")

print("\nScript finished.")
# Out:
# --- 1. Data Loading ---
# Fetching data (limit=None)...
# Data loaded. Shape: (2728, 112). Time: 0.22s
#
# Raw Dataset Information:
# Time range: 2025-04-04 20:17:00 to 2025-04-05 19:00:00
# Symbols: ['BTC' 'SOL']
#
# --- 2. Data Cleaning ---
# Missing/Infinite before: 1824 / 0
# Missing/Infinite after: 0 / 0
# Rows removed: 336 (12.32%)
#
# --- 3. Feature Engineering ---
# Creating dummy variables for symbols (BTC, SOL)...
# Creating binary target 'target' (1-hour return >= 0.1%)...
# NaN values in target before drop: 0
# Rows after removing NaN targets: 2392
#
# Target variable distribution:
#   0 (< 0.1% return): 1712 (71.57%)
#   1 (>= 0.1% return): 680 (28.43%)
#
# --- 4. Final Preparation ---
# Final DataFrame shape for backtesting: (2392, 115)
#
# --- Feature Selection ---
# Target Column: 'target'
# Number of features selected: 112
#   - 'BTC' included: True
#   - 'SOL' included: True
#
# --- 5. Starting Walk-Forward Validation ---
# Total rows: 2392, Train: 180, Test: 60, Step: 2
# Estimated iterations: 1076
# Inner CV Grid: {'max_depth': [3, 5], 'n_estimators': [150, 350], 'eta': [0.04, 0.12], 'subsample': [0.8, 1.0], 'alpha': [0.3, 0.7], 'min_child_weight': [2, 5]}
# ------------------------------
#
# Iter 1/1076: Train[0:179], Test[180:239], Best Params: {'alpha': 0.3, 'eta': 0.12, 'max_depth': 3, 'min_child_weight': 2, 'n_estimators': 150, 'subsample': 0.8}
# Warning iter 32: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 33: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 34: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 35: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 36: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 37: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 38: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 39: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 40: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 41: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 42: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 43: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 44: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 45: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 46: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 47: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 48: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 49: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 50: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 50: Validation set has only one class, skipping inner CV.
#
# Iter 50/1076: Train[98:277], Test[278:337], Best Params: {'alpha': 0.3, 'eta': 0.04, 'max_depth': 3, 'min_child_weight': 2, 'n_estimators': 150, 'subsample': 0.8}
# Warning iter 51: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 51: Validation set has only one class, skipping inner CV.
# Warning iter 52: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 52: Validation set has only one class, skipping inner CV.
# Warning iter 53: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 53: Validation set has only one class, skipping inner CV.
# Warning iter 54: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 54: Validation set has only one class, skipping inner CV.
# Warning iter 55: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 55: Validation set has only one class, skipping inner CV.
# Warning iter 56: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 56: Validation set has only one class, skipping inner CV.
# Warning iter 57: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 57: Validation set has only one class, skipping inner CV.
# Warning iter 58: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 58: Validation set has only one class, skipping inner CV.
# Warning iter 59: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 59: Validation set has only one class, skipping inner CV.
# Warning iter 60: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 60: Validation set has only one class, skipping inner CV.
# Warning iter 61: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 61: Validation set has only one class, skipping inner CV.
# Warning iter 62: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 62: Validation set has only one class, skipping inner CV.
# Warning iter 63: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 63: Validation set has only one class, skipping inner CV.
# Warning iter 64: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 64: Validation set has only one class, skipping inner CV.
# Warning iter 65: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 65: Validation set has only one class, skipping inner CV.
# Warning iter 66: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 66: Validation set has only one class, skipping inner CV.
# Warning iter 67: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 67: Validation set has only one class, skipping inner CV.
# Warning iter 68: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 68: Validation set has only one class, skipping inner CV.
# Warning iter 69: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 69: Validation set has only one class, skipping inner CV.
# Warning iter 70: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 70: Validation set has only one class, skipping inner CV.
# Warning iter 71: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 71: Validation set has only one class, skipping inner CV.
# Warning iter 72: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 72: Validation set has only one class, skipping inner CV.
# Warning iter 73: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 73: Validation set has only one class, skipping inner CV.
# Warning iter 74: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 74: Validation set has only one class, skipping inner CV.
# Warning iter 75: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 75: Validation set has only one class, skipping inner CV.
# Warning iter 76: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 76: Validation set has only one class, skipping inner CV.
# Warning iter 77: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 77: Validation set has only one class, skipping inner CV.
# Warning iter 78: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 78: Validation set has only one class, skipping inner CV.
# Warning iter 79: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 79: Validation set has only one class, skipping inner CV.
# Warning iter 80: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 80: Validation set has only one class, skipping inner CV.
# Warning iter 81: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 81: Validation set has only one class, skipping inner CV.
# Warning iter 82: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 82: Validation set has only one class, skipping inner CV.
# Warning iter 83: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 83: Validation set has only one class, skipping inner CV.
# Warning iter 84: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 84: Validation set has only one class, skipping inner CV.
# Warning iter 85: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 85: Validation set has only one class, skipping inner CV.
# Warning iter 86: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 86: Validation set has only one class, skipping inner CV.
# Warning iter 87: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 87: Validation set has only one class, skipping inner CV.
# Warning iter 88: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 88: Validation set has only one class, skipping inner CV.
# Warning iter 89: Validation set has only one class, skipping inner CV.
# Warning iter 90: Validation set has only one class, skipping inner CV.
# Warning iter 91: Validation set has only one class, skipping inner CV.
# Warning iter 92: Validation set has only one class, skipping inner CV.
# Warning iter 93: Validation set has only one class, skipping inner CV.
# Warning iter 94: Validation set has only one class, skipping inner CV.
# Warning iter 95: Validation set has only one class, skipping inner CV.
# Warning iter 96: Validation set has only one class, skipping inner CV.
# Warning iter 97: Validation set has only one class, skipping inner CV.
# Warning iter 98: Validation set has only one class, skipping inner CV.
# Warning iter 99: Validation set has only one class, skipping inner CV.
# Warning iter 100: Validation set has only one class, skipping inner CV.
#
# Iter 100/1076: Train[198:377], Test[378:437], Best Params: {'alpha': 0.3, 'eta': 0.04, 'max_depth': 3, 'min_child_weight': 2, 'n_estimators': 150, 'subsample': 0.8}
# Warning iter 101: Validation set has only one class, skipping inner CV.
# Warning iter 102: Validation set has only one class, skipping inner CV.
# Warning iter 103: Validation set has only one class, skipping inner CV.
# Warning iter 104: Validation set has only one class, skipping inner CV.
# Warning iter 105: Validation set has only one class, skipping inner CV.
# Warning iter 106: Validation set has only one class, skipping inner CV.
# Warning iter 107: Validation set has only one class, skipping inner CV.
# Warning iter 108: Validation set has only one class, skipping inner CV.
# Warning iter 109: Validation set has only one class, skipping inner CV.
# Warning iter 110: Validation set has only one class, skipping inner CV.
# Warning iter 111: Validation set has only one class, skipping inner CV.
# Warning iter 112: Validation set has only one class, skipping inner CV.
# Warning iter 113: Validation set has only one class, skipping inner CV.
# Warning iter 114: Validation set has only one class, skipping inner CV.
# Warning iter 115: Validation set has only one class, skipping inner CV.
# Warning iter 116: Validation set has only one class, skipping inner CV.
# Warning iter 117: Validation set has only one class, skipping inner CV.
# Warning iter 118: Validation set has only one class, skipping inner CV.
# Warning iter 122: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 123: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 124: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 125: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 126: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 127: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 128: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 140: Validation set has only one class, skipping inner CV.
# Warning iter 141: Validation set has only one class, skipping inner CV.
# Warning iter 142: Validation set has only one class, skipping inner CV.
# Warning iter 143: Validation set has only one class, skipping inner CV.
# Warning iter 144: Validation set has only one class, skipping inner CV.
# Warning iter 145: Validation set has only one class, skipping inner CV.
# Warning iter 146: Validation set has only one class, skipping inner CV.
# Warning iter 147: Validation set has only one class, skipping inner CV.
# Warning iter 148: Validation set has only one class, skipping inner CV.
# Warning iter 149: Validation set has only one class, skipping inner CV.
# Warning iter 150: Validation set has only one class, skipping inner CV.
#
# Iter 150/1076: Train[298:477], Test[478:537], Best Params: {'alpha': 0.3, 'eta': 0.04, 'max_depth': 3, 'min_child_weight': 2, 'n_estimators': 150, 'subsample': 0.8}
# Warning iter 151: Validation set has only one class, skipping inner CV.
# Warning iter 152: Validation set has only one class, skipping inner CV.
# Warning iter 153: Validation set has only one class, skipping inner CV.
# Warning iter 154: Validation set has only one class, skipping inner CV.
# Warning iter 155: Validation set has only one class, skipping inner CV.
# Warning iter 156: Validation set has only one class, skipping inner CV.
# Warning iter 157: Validation set has only one class, skipping inner CV.
# Warning iter 158: Validation set has only one class, skipping inner CV.
# Warning iter 191: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 192: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 193: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 194: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 195: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 196: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 197: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 198: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 199: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 200: Test data has only one class ([0]). Metrics might be affected.
#
# Iter 200/1076: Train[398:577], Test[578:637], Best Params: {'alpha': 0.3, 'eta': 0.04, 'max_depth': 3, 'min_child_weight': 2, 'n_estimators': 150, 'subsample': 0.8}
# Warning iter 201: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 202: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 203: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 204: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 205: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 206: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 207: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 208: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 209: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 209: Validation set has only one class, skipping inner CV.
# Warning iter 210: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 210: Validation set has only one class, skipping inner CV.
# Warning iter 211: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 211: Validation set has only one class, skipping inner CV.
# Warning iter 212: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 212: Validation set has only one class, skipping inner CV.
# Warning iter 213: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 213: Validation set has only one class, skipping inner CV.
# Warning iter 214: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 214: Validation set has only one class, skipping inner CV.
# Warning iter 215: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 215: Validation set has only one class, skipping inner CV.
# Warning iter 216: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 216: Validation set has only one class, skipping inner CV.
# Warning iter 217: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 217: Validation set has only one class, skipping inner CV.
# Warning iter 218: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 218: Validation set has only one class, skipping inner CV.
# Warning iter 219: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 219: Validation set has only one class, skipping inner CV.
# Warning iter 220: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 220: Validation set has only one class, skipping inner CV.
# Warning iter 221: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 221: Validation set has only one class, skipping inner CV.
# Warning iter 222: Validation set has only one class, skipping inner CV.
# Warning iter 223: Validation set has only one class, skipping inner CV.
# Warning iter 224: Validation set has only one class, skipping inner CV.
# Warning iter 225: Validation set has only one class, skipping inner CV.
# Warning iter 226: Validation set has only one class, skipping inner CV.
# Warning iter 227: Validation set has only one class, skipping inner CV.
# Warning iter 228: Validation set has only one class, skipping inner CV.
# Warning iter 229: Validation set has only one class, skipping inner CV.
# Warning iter 230: Validation set has only one class, skipping inner CV.
# Warning iter 231: Validation set has only one class, skipping inner CV.
# Warning iter 232: Validation set has only one class, skipping inner CV.
# Warning iter 233: Validation set has only one class, skipping inner CV.
# Warning iter 234: Validation set has only one class, skipping inner CV.
# Warning iter 235: Validation set has only one class, skipping inner CV.
# Warning iter 236: Validation set has only one class, skipping inner CV.
# Warning iter 237: Validation set has only one class, skipping inner CV.
# Warning iter 238: Validation set has only one class, skipping inner CV.
# Warning iter 239: Validation set has only one class, skipping inner CV.
# Warning iter 240: Validation set has only one class, skipping inner CV.
# Warning iter 241: Validation set has only one class, skipping inner CV.
# Warning iter 242: Validation set has only one class, skipping inner CV.
# Warning iter 243: Validation set has only one class, skipping inner CV.
# Warning iter 244: Validation set has only one class, skipping inner CV.
# Warning iter 245: Validation set has only one class, skipping inner CV.
# Warning iter 246: Validation set has only one class, skipping inner CV.
# Warning iter 247: Validation set has only one class, skipping inner CV.
# Warning iter 248: Validation set has only one class, skipping inner CV.
# Warning iter 249: Validation set has only one class, skipping inner CV.
# Warning iter 250: Validation set has only one class, skipping inner CV.
#
# Iter 250/1076: Train[498:677], Test[678:737], Best Params: {'alpha': 0.3, 'eta': 0.04, 'max_depth': 3, 'min_child_weight': 2, 'n_estimators': 150, 'subsample': 0.8}
# Warning iter 251: Validation set has only one class, skipping inner CV.
# Warning iter 286: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 287: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 288: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 289: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 290: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 291: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 292: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 293: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 294: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 295: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 296: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 297: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 298: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 299: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 300: Test data has only one class ([0]). Metrics might be affected.
#
# Iter 300/1076: Train[598:777], Test[778:837], Best Params: {'alpha': 0.3, 'eta': 0.04, 'max_depth': 3, 'min_child_weight': 2, 'n_estimators': 150, 'subsample': 1.0}
# Warning iter 301: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 302: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 303: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 304: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 304: Validation set has only one class, skipping inner CV.
# Warning iter 305: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 305: Validation set has only one class, skipping inner CV.
# Warning iter 306: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 306: Validation set has only one class, skipping inner CV.
# Warning iter 307: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 307: Validation set has only one class, skipping inner CV.
# Warning iter 308: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 308: Validation set has only one class, skipping inner CV.
# Warning iter 309: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 309: Validation set has only one class, skipping inner CV.
# Warning iter 310: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 310: Validation set has only one class, skipping inner CV.
# Warning iter 311: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 311: Validation set has only one class, skipping inner CV.
# Warning iter 312: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 312: Validation set has only one class, skipping inner CV.
# Warning iter 313: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 313: Validation set has only one class, skipping inner CV.
# Warning iter 314: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 314: Validation set has only one class, skipping inner CV.
# Warning iter 315: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 315: Validation set has only one class, skipping inner CV.
# Warning iter 316: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 316: Validation set has only one class, skipping inner CV.
# Warning iter 317: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 317: Validation set has only one class, skipping inner CV.
# Warning iter 318: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 318: Validation set has only one class, skipping inner CV.
# Warning iter 319: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 319: Validation set has only one class, skipping inner CV.
# Warning iter 320: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 320: Validation set has only one class, skipping inner CV.
# Warning iter 321: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 321: Validation set has only one class, skipping inner CV.
# Warning iter 322: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 322: Validation set has only one class, skipping inner CV.
# Warning iter 323: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 323: Validation set has only one class, skipping inner CV.
# Warning iter 324: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 324: Validation set has only one class, skipping inner CV.
# Warning iter 325: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 325: Validation set has only one class, skipping inner CV.
# Warning iter 326: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 326: Validation set has only one class, skipping inner CV.
# Warning iter 327: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 327: Validation set has only one class, skipping inner CV.
# Warning iter 328: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 328: Validation set has only one class, skipping inner CV.
# Warning iter 329: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 329: Validation set has only one class, skipping inner CV.
# Warning iter 330: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 330: Validation set has only one class, skipping inner CV.
# Warning iter 331: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 331: Validation set has only one class, skipping inner CV.
# Warning iter 332: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 332: Validation set has only one class, skipping inner CV.
# Warning iter 333: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 333: Validation set has only one class, skipping inner CV.
# Warning iter 334: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 334: Validation set has only one class, skipping inner CV.
# Warning iter 335: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 335: Validation set has only one class, skipping inner CV.
# Warning iter 336: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 336: Validation set has only one class, skipping inner CV.
# Warning iter 337: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 337: Validation set has only one class, skipping inner CV.
# Warning iter 338: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 338: Validation set has only one class, skipping inner CV.
# Warning iter 339: Validation set has only one class, skipping inner CV.
# Warning iter 340: Validation set has only one class, skipping inner CV.
# Warning iter 341: Validation set has only one class, skipping inner CV.
# Warning iter 342: Validation set has only one class, skipping inner CV.
# Warning iter 343: Validation set has only one class, skipping inner CV.
# Warning iter 344: Validation set has only one class, skipping inner CV.
# Warning iter 345: Validation set has only one class, skipping inner CV.
# Warning iter 346: Validation set has only one class, skipping inner CV.
# Warning iter 347: Validation set has only one class, skipping inner CV.
# Warning iter 348: Validation set has only one class, skipping inner CV.
# Warning iter 349: Validation set has only one class, skipping inner CV.
# Warning iter 350: Validation set has only one class, skipping inner CV.
#
# Iter 350/1076: Train[698:877], Test[878:937], Best Params: {'alpha': 0.3, 'eta': 0.04, 'max_depth': 3, 'min_child_weight': 2, 'n_estimators': 150, 'subsample': 0.8}
# Warning iter 351: Validation set has only one class, skipping inner CV.
# Warning iter 352: Validation set has only one class, skipping inner CV.
# Warning iter 353: Validation set has only one class, skipping inner CV.
# Warning iter 354: Validation set has only one class, skipping inner CV.
# Warning iter 355: Validation set has only one class, skipping inner CV.
# Warning iter 356: Validation set has only one class, skipping inner CV.
# Warning iter 357: Validation set has only one class, skipping inner CV.
# Warning iter 358: Validation set has only one class, skipping inner CV.
# Warning iter 359: Validation set has only one class, skipping inner CV.
# Warning iter 360: Validation set has only one class, skipping inner CV.
# Warning iter 361: Validation set has only one class, skipping inner CV.
# Warning iter 362: Validation set has only one class, skipping inner CV.
# Warning iter 363: Validation set has only one class, skipping inner CV.
# Warning iter 364: Validation set has only one class, skipping inner CV.
# Warning iter 365: Validation set has only one class, skipping inner CV.
# Warning iter 366: Validation set has only one class, skipping inner CV.
# Warning iter 367: Validation set has only one class, skipping inner CV.
# Warning iter 368: Validation set has only one class, skipping inner CV.
#
# Iter 400/1076: Train[798:977], Test[978:1037], Best Params: {'alpha': 0.3, 'eta': 0.04, 'max_depth': 3, 'min_child_weight': 2, 'n_estimators': 150, 'subsample': 0.8}
#
# Iter 450/1076: Train[898:1077], Test[1078:1137], Best Params: {'alpha': 0.7, 'eta': 0.04, 'max_depth': 3, 'min_child_weight': 2, 'n_estimators': 150, 'subsample': 0.8}
# Warning iter 469: Test data has only one class ([1]). Metrics might be affected.
# Warning iter 470: Test data has only one class ([1]). Metrics might be affected.
# Warning iter 471: Test data has only one class ([1]). Metrics might be affected.
# Warning iter 472: Test data has only one class ([1]). Metrics might be affected.
# Warning iter 473: Test data has only one class ([1]). Metrics might be affected.
# Warning iter 474: Test data has only one class ([1]). Metrics might be affected.
# Warning iter 475: Test data has only one class ([1]). Metrics might be affected.
# Warning iter 476: Test data has only one class ([1]). Metrics might be affected.
# Warning iter 477: Test data has only one class ([1]). Metrics might be affected.
# Warning iter 478: Test data has only one class ([1]). Metrics might be affected.
# Warning iter 479: Test data has only one class ([1]). Metrics might be affected.
# Warning iter 480: Test data has only one class ([1]). Metrics might be affected.
# Warning iter 481: Test data has only one class ([1]). Metrics might be affected.
# Warning iter 482: Test data has only one class ([1]). Metrics might be affected.
# Warning iter 483: Test data has only one class ([1]). Metrics might be affected.
# Warning iter 484: Test data has only one class ([1]). Metrics might be affected.
# Warning iter 485: Test data has only one class ([1]). Metrics might be affected.
# Warning iter 486: Test data has only one class ([1]). Metrics might be affected.
# Warning iter 487: Test data has only one class ([1]). Metrics might be affected.
# Warning iter 487: Validation set has only one class, skipping inner CV.
# Warning iter 488: Validation set has only one class, skipping inner CV.
# Warning iter 489: Validation set has only one class, skipping inner CV.
# Warning iter 490: Validation set has only one class, skipping inner CV.
# Warning iter 491: Validation set has only one class, skipping inner CV.
# Warning iter 492: Validation set has only one class, skipping inner CV.
# Warning iter 493: Validation set has only one class, skipping inner CV.
# Warning iter 494: Validation set has only one class, skipping inner CV.
# Warning iter 495: Validation set has only one class, skipping inner CV.
# Warning iter 496: Validation set has only one class, skipping inner CV.
# Warning iter 497: Validation set has only one class, skipping inner CV.
# Warning iter 498: Validation set has only one class, skipping inner CV.
# Warning iter 499: Validation set has only one class, skipping inner CV.
# Warning iter 500: Validation set has only one class, skipping inner CV.
#
# Iter 500/1076: Train[998:1177], Test[1178:1237], Best Params: {'alpha': 0.3, 'eta': 0.04, 'max_depth': 3, 'min_child_weight': 2, 'n_estimators': 150, 'subsample': 0.8}
# Warning iter 501: Validation set has only one class, skipping inner CV.
# Warning iter 502: Validation set has only one class, skipping inner CV.
# Warning iter 503: Validation set has only one class, skipping inner CV.
# Warning iter 504: Validation set has only one class, skipping inner CV.
# Warning iter 505: Validation set has only one class, skipping inner CV.
# Warning iter 506: Validation set has only one class, skipping inner CV.
# Warning iter 507: Validation set has only one class, skipping inner CV.
# Warning iter 508: Validation set has only one class, skipping inner CV.
# Warning iter 509: Validation set has only one class, skipping inner CV.
# Warning iter 510: Validation set has only one class, skipping inner CV.
# Warning iter 511: Validation set has only one class, skipping inner CV.
# Warning iter 512: Validation set has only one class, skipping inner CV.
# Warning iter 513: Validation set has only one class, skipping inner CV.
# Warning iter 514: Validation set has only one class, skipping inner CV.
# Warning iter 515: Validation set has only one class, skipping inner CV.
# Warning iter 516: Validation set has only one class, skipping inner CV.
# Warning iter 517: Validation set has only one class, skipping inner CV.
# Warning iter 522: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 523: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 524: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 525: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 526: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 527: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 528: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 529: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 530: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 531: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 532: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 533: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 534: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 535: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 536: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 537: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 538: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 539: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 540: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 540: Validation set has only one class, skipping inner CV.
# Warning iter 541: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 541: Validation set has only one class, skipping inner CV.
# Warning iter 542: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 542: Validation set has only one class, skipping inner CV.
# Warning iter 543: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 543: Validation set has only one class, skipping inner CV.
# Warning iter 544: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 544: Validation set has only one class, skipping inner CV.
# Warning iter 545: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 545: Validation set has only one class, skipping inner CV.
# Warning iter 546: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 546: Validation set has only one class, skipping inner CV.
# Warning iter 547: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 547: Validation set has only one class, skipping inner CV.
# Warning iter 548: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 548: Validation set has only one class, skipping inner CV.
# Warning iter 549: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 549: Validation set has only one class, skipping inner CV.
# Warning iter 550: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 550: Validation set has only one class, skipping inner CV.
#
# Iter 550/1076: Train[1098:1277], Test[1278:1337], Best Params: {'alpha': 0.3, 'eta': 0.04, 'max_depth': 3, 'min_child_weight': 2, 'n_estimators': 150, 'subsample': 0.8}
# Warning iter 551: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 551: Validation set has only one class, skipping inner CV.
# Warning iter 552: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 552: Validation set has only one class, skipping inner CV.
# Warning iter 553: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 553: Validation set has only one class, skipping inner CV.
# Warning iter 554: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 554: Validation set has only one class, skipping inner CV.
# Warning iter 555: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 555: Validation set has only one class, skipping inner CV.
# Warning iter 556: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 556: Validation set has only one class, skipping inner CV.
# Warning iter 557: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 557: Validation set has only one class, skipping inner CV.
# Warning iter 558: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 558: Validation set has only one class, skipping inner CV.
# Warning iter 559: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 559: Validation set has only one class, skipping inner CV.
# Warning iter 560: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 560: Validation set has only one class, skipping inner CV.
# Warning iter 561: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 561: Validation set has only one class, skipping inner CV.
# Warning iter 562: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 562: Validation set has only one class, skipping inner CV.
# Warning iter 563: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 563: Validation set has only one class, skipping inner CV.
# Warning iter 564: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 564: Validation set has only one class, skipping inner CV.
# Warning iter 565: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 565: Validation set has only one class, skipping inner CV.
# Warning iter 566: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 566: Validation set has only one class, skipping inner CV.
# Warning iter 567: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 567: Validation set has only one class, skipping inner CV.
# Warning iter 568: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 568: Validation set has only one class, skipping inner CV.
# Warning iter 569: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 569: Validation set has only one class, skipping inner CV.
# Warning iter 570: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 570: Validation set has only one class, skipping inner CV.
# Warning iter 571: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 571: Validation set has only one class, skipping inner CV.
# Warning iter 572: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 572: Validation set has only one class, skipping inner CV.
# Warning iter 573: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 573: Validation set has only one class, skipping inner CV.
# Warning iter 574: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 574: Validation set has only one class, skipping inner CV.
# Warning iter 575: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 575: Validation set has only one class, skipping inner CV.
# Warning iter 576: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 576: Validation set has only one class, skipping inner CV.
# Warning iter 577: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 577: Validation set has only one class, skipping inner CV.
# Warning iter 578: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 578: Validation set has only one class, skipping inner CV.
# Warning iter 579: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 579: Validation set has only one class, skipping inner CV.
# Warning iter 580: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 580: Validation set has only one class, skipping inner CV.
# Warning iter 581: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 581: Validation set has only one class, skipping inner CV.
# Warning iter 582: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 582: Validation set has only one class, skipping inner CV.
# Warning iter 583: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 583: Validation set has only one class, skipping inner CV.
# Warning iter 584: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 584: Validation set has only one class, skipping inner CV.
# Warning iter 585: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 585: Validation set has only one class, skipping inner CV.
# Warning iter 586: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 586: Validation set has only one class, skipping inner CV.
# Warning iter 587: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 587: Validation set has only one class, skipping inner CV.
# Warning iter 588: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 588: Validation set has only one class, skipping inner CV.
# Warning iter 589: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 589: Validation set has only one class, skipping inner CV.
# Warning iter 590: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 590: Validation set has only one class, skipping inner CV.
# Warning iter 591: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 591: Validation set has only one class, skipping inner CV.
# Warning iter 592: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 592: Validation set has only one class, skipping inner CV.
# Warning iter 593: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 593: Validation set has only one class, skipping inner CV.
# Warning iter 594: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 594: Validation set has only one class, skipping inner CV.
# Warning iter 595: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 595: Validation set has only one class, skipping inner CV.
# Warning iter 596: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 596: Validation set has only one class, skipping inner CV.
# Warning iter 597: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 597: Validation set has only one class, skipping inner CV.
# Warning iter 598: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 598: Validation set has only one class, skipping inner CV.
# Warning iter 599: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 599: Validation set has only one class, skipping inner CV.
# Warning iter 600: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 600: Validation set has only one class, skipping inner CV.
#
# Iter 600/1076: Train[1198:1377], Test[1378:1437], Best Params: {'alpha': 0.3, 'eta': 0.04, 'max_depth': 3, 'min_child_weight': 2, 'n_estimators': 150, 'subsample': 0.8}
# Warning iter 601: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 601: Validation set has only one class, skipping inner CV.
# Warning iter 602: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 602: Validation set has only one class, skipping inner CV.
# Warning iter 603: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 603: Validation set has only one class, skipping inner CV.
# Warning iter 604: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 604: Validation set has only one class, skipping inner CV.
# Warning iter 605: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 605: Validation set has only one class, skipping inner CV.
# Warning iter 606: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 606: Validation set has only one class, skipping inner CV.
# Warning iter 607: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 607: Validation set has only one class, skipping inner CV.
# Warning iter 608: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 608: Validation set has only one class, skipping inner CV.
# Warning iter 609: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 609: Validation set has only one class, skipping inner CV.
# Warning iter 610: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 610: Validation set has only one class, skipping inner CV.
# Warning iter 611: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 611: Validation set has only one class, skipping inner CV.
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# ...
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Skipping iter 612: Full training data has only one class ([0]).
# Warning iter 648: Validation set has only one class, skipping inner CV.
# Warning iter 649: Validation set has only one class, skipping inner CV.
#
# Iter 650/1076: Train[1614:1793], Test[1794:1853], Best Params: {'alpha': 0.3, 'eta': 0.04, 'max_depth': 3, 'min_child_weight': 2, 'n_estimators': 150, 'subsample': 0.8}
# Warning iter 670: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 671: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 672: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 673: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 674: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 675: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 676: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 677: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 678: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 679: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 680: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 681: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 682: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 683: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 688: Validation set has only one class, skipping inner CV.
# Warning iter 689: Validation set has only one class, skipping inner CV.
# Warning iter 690: Validation set has only one class, skipping inner CV.
# Warning iter 691: Validation set has only one class, skipping inner CV.
# Warning iter 692: Validation set has only one class, skipping inner CV.
# Warning iter 693: Validation set has only one class, skipping inner CV.
# Warning iter 694: Validation set has only one class, skipping inner CV.
# Warning iter 695: Validation set has only one class, skipping inner CV.
# Warning iter 696: Validation set has only one class, skipping inner CV.
# Warning iter 697: Validation set has only one class, skipping inner CV.
# Warning iter 698: Validation set has only one class, skipping inner CV.
# Warning iter 699: Validation set has only one class, skipping inner CV.
# Warning iter 700: Validation set has only one class, skipping inner CV.
#
# Iter 700/1076: Train[1714:1893], Test[1894:1953], Best Params: {'alpha': 0.3, 'eta': 0.04, 'max_depth': 3, 'min_child_weight': 2, 'n_estimators': 150, 'subsample': 0.8}
# Warning iter 701: Validation set has only one class, skipping inner CV.
# Warning iter 702: Validation set has only one class, skipping inner CV.
# Warning iter 703: Validation set has only one class, skipping inner CV.
# Warning iter 704: Validation set has only one class, skipping inner CV.
# Warning iter 705: Validation set has only one class, skipping inner CV.
# Warning iter 706: Validation set has only one class, skipping inner CV.
# Warning iter 707: Validation set has only one class, skipping inner CV.
# Warning iter 708: Validation set has only one class, skipping inner CV.
# Warning iter 709: Validation set has only one class, skipping inner CV.
# Warning iter 710: Validation set has only one class, skipping inner CV.
# Warning iter 711: Validation set has only one class, skipping inner CV.
# Warning iter 712: Validation set has only one class, skipping inner CV.
# Warning iter 713: Validation set has only one class, skipping inner CV.
#
# Iter 750/1076: Train[1814:1993], Test[1994:2053], Best Params: {'alpha': 0.3, 'eta': 0.04, 'max_depth': 3, 'min_child_weight': 2, 'n_estimators': 150, 'subsample': 0.8}
# Warning iter 759: Validation set has only one class, skipping inner CV.
# Warning iter 760: Validation set has only one class, skipping inner CV.
# Warning iter 761: Validation set has only one class, skipping inner CV.
#
# Iter 800/1076: Train[1914:2093], Test[2094:2153], Best Params: {'alpha': 0.3, 'eta': 0.04, 'max_depth': 3, 'min_child_weight': 2, 'n_estimators': 150, 'subsample': 0.8}
# Warning iter 806: Validation set has only one class, skipping inner CV.
# Warning iter 807: Validation set has only one class, skipping inner CV.
# Warning iter 847: Validation set has only one class, skipping inner CV.
# Warning iter 848: Validation set has only one class, skipping inner CV.
# Warning iter 849: Validation set has only one class, skipping inner CV.
# Warning iter 850: Validation set has only one class, skipping inner CV.
#
# Iter 850/1076: Train[2014:2193], Test[2194:2253], Best Params: {'alpha': 0.3, 'eta': 0.04, 'max_depth': 3, 'min_child_weight': 2, 'n_estimators': 150, 'subsample': 0.8}
# Warning iter 851: Validation set has only one class, skipping inner CV.
# Warning iter 852: Validation set has only one class, skipping inner CV.
# Warning iter 853: Validation set has only one class, skipping inner CV.
# Warning iter 854: Validation set has only one class, skipping inner CV.
# Warning iter 855: Validation set has only one class, skipping inner CV.
# Warning iter 856: Validation set has only one class, skipping inner CV.
# Warning iter 857: Validation set has only one class, skipping inner CV.
# Warning iter 858: Validation set has only one class, skipping inner CV.
# Warning iter 889: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 890: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 891: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 892: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 893: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 894: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 895: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 896: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 897: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 898: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 899: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 900: Test data has only one class ([0]). Metrics might be affected.
#
# Iter 900/1076: Train[2114:2293], Test[2294:2353], Best Params: {'alpha': 0.3, 'eta': 0.12, 'max_depth': 3, 'min_child_weight': 2, 'n_estimators': 150, 'subsample': 0.8}
# Warning iter 901: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 902: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 903: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 904: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 905: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 906: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 907: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 907: Validation set has only one class, skipping inner CV.
# Warning iter 908: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 908: Validation set has only one class, skipping inner CV.
# Warning iter 909: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 909: Validation set has only one class, skipping inner CV.
# Warning iter 910: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 910: Validation set has only one class, skipping inner CV.
# Warning iter 911: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 911: Validation set has only one class, skipping inner CV.
# Warning iter 912: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 912: Validation set has only one class, skipping inner CV.
# Warning iter 913: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 913: Validation set has only one class, skipping inner CV.
# Warning iter 914: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 914: Validation set has only one class, skipping inner CV.
# Warning iter 915: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 915: Validation set has only one class, skipping inner CV.
# Warning iter 916: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 916: Validation set has only one class, skipping inner CV.
# Warning iter 917: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 917: Validation set has only one class, skipping inner CV.
# Warning iter 918: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 918: Validation set has only one class, skipping inner CV.
# Warning iter 919: Test data has only one class ([0]). Metrics might be affected.
# Warning iter 919: Validation set has only one class, skipping inner CV.
#
# Stopping: Test window end index (2394) > total rows (2392).
# ------------------------------
# Walk-Forward Validation finished in 4571.29 seconds (76.19 minutes).
#
# --- 6. Final Results ---
#
# --- Average Walk-Forward Validation Results (XGBoost with Inner CV) ---
# Total Folds / Iterations Evaluated: 919
# Target Threshold: 0.1%
# Average Accuracy:  0.7072
# Average Precision: 0.4496 (for class 1: return >= 0.1%)
# Average Recall:    0.3079 (for class 1: return >= 0.1%)
# Average F1-Score:  0.3188 (for class 1: return >= 0.1%)
#
# --- Standard Deviation of Metrics Across Folds ---
# Std Dev Accuracy:  0.2077
# Std Dev Precision: 0.4319
# Std Dev Recall:    0.3408
# Std Dev F1-Score:  0.3275
#
# Script finished.

# %% [markdown]
# Computational Overhead: This adds a substantial calculation step before every single training iteration. At a 5-minute retraining frequency, calculating weighted importances across 100 past results, selecting features, and subsetting the data adds significant time and complexity to each cycle. This might make keeping up with the 5-minute interval difficult.
